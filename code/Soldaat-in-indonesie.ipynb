# %% [markdown]
# ## Zoeken op basis van Text & Data Mining
#
#
# In dit tutorial vind je uitleg over hoe je het corpus van "Soldaat in Indonesie" kunt doorzoeken op basis van Text & Data Mining. Er wordt hierbij gebruik gemaakt van de programmeertaal Python. Dit tutorial is echter geen basis-introductie tot programmeren in Python. De voorbeelden hieronder laten alleen zien hoe je dit corpus kunt doorzoeken met behulp van bestaande modules en bibliotheken. Modules zijn kant en klare en herbruikbare ‘pakketjes’ software code waarin specifieke functionaliteiten worden aangeboden. De meeste modules zijn generiek, en kunnen dus op verschillende datasets worden toegepast waarbij je dan alleen bijvoorbeeld de zoekterm moet aanpassen of het bestand waarin je wilt zoeken.
#
#
# ## Installeren en importeren van modules
#
#
# In dit tutorial maken we gebruik van de module ‘os’, dat staat voor ‘operating system’. De module biedt een aantal functies waarmee je contact kunt maken met het besturingssysteem van je computer. Een van die functies is dat je de inhoud van een map op je computer kunt lezen.
#
# 'nltk' is een verzameling modules die je kunt gebruiken bij analyses op het gebied van Natural Language Processing. Zo kun je paragrafen op laten splitsen in afzonderlijke zinnen, je kunt de stam van een woord of een werkwoord vinden, en je kunt de software opdracht geven om grammaticale categorieën toe te voegen aan woorden (werkwoord, eigennaam, lidwoord, zelfstandig naamwoord).
#
# De module ‘kitlvTdm’ is specifiek ontwikkeld voor dit KITLV corpus van memoires en bevat een aantal basisinstructies op op het gebied van Text & Data Mining.
#
# Als je Python hebt geïnstalleerd via Anaconda en als je hiernaast ook alle benodigde bestanden uit de Github-repository op de juiste manier hebt gekopieerd naar je computer, hoef je deze modules niet meer afzonderlijk te installeren. Anaconda bevat namelijk alle benodigde modules.
#
# Als je Python op een andere manier hebt geïnstalleerd, dan is het wellicht wel nodig om die modules te installeren. Je kunt dit vergelijken met het installeren van een nieuw programma op je computer. Na de installatie komen alle functionaliteiten van deze module of bibliotheek beschikbaar. Modules en bibliotheken kunnen via de onderstaande commando's worden geïnstalleerd. Plaats de cursor in de onderstaande cel, en klik daarna op [shift] + [Enter]. Hierna verschijnen er, als het goed is, een aantal meldingen over het installatieproces.

# %%
# !conda install --yes --prefix {sys.prefix} os
# !conda install --yes --prefix {sys.prefix} nltk
# !conda install --yes --prefix {sys.prefix} matplotlib 
# !conda install --yes --prefix {sys.prefix} re

# %% [markdown]
# Als alle modules correct zijn geïnstalleerd kunnen ze in de code worden geïmporteerd. Zo'n import zorgt er vervolgens voor dat alle code ook in het huidige programma gebruikt kunnen worden.
#
# Plaats de cursor in de onderstaande cel , en klik daarna op [shift] + [Enter]. Als alle modules goed zijn geïnstalleerd verschijnen er hierna geen meldingen.

# %%
import os
from os.path import isfile, join , isdir
import string
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
from kitlvTdm import *
import pandas as pd

# %% [markdown]
# ## 1. Zoeken naar een specifieke term
#
# Je kunt op de eerste plaats op zoek gaan naar passages met een bepaald trefwoord in de verzameling egodocumenten. In de onderstaande code moet dit trefwoord worden opgegeven als waarde van de variabele `search_term` (bv. “Baboe” of “geweer”). Binnen de aanhalingstekens kan de zoekterm dus worden aangepast.
#
# Wanneer de code wordt uitgevoerd toont het programma een lijst van alle documenten waar de opgegeven term in voorkomt, samen met alle gevonden passages. De resultaten worden weergegeven als een zogenaamde ‘concordantie’. Zo'n concordantie wordt ook wel een *keyword in context* (KWIC) lijst genoemd. Dit betekent dat de term die je zoekt wordt weergegeven met een specifiek aantal woorden voor en na de opgegeven zoekterm. De grootte van deze passages kan worden bepaald met de variabele `window`. Het getal dat wordt opgegeven bepaalt het aantal woorden voorafgaand aan en volgend op de gebruikte term. Als die op bv. op 3 staat, en je zoekt op “geweer”, dan kun je een zin terugkrijgen als ‘ik pak mijn geweer en schiet op’. Het odnerstaande voorbeeld gebruikt de term ‘baboe’ oftewel ‘wasvrouw’. Dit is een woord dat in veel van de ego-documenten voorkomt.
#
# Tijdens het digitaliseren van de egodocumenten in het corpus van 'Soldaat in Indonesië' hebben alle documenten een eigen numerieke code gekregen. Deze codes zijn ook gebruikt in de bestandsnamen. De functie 'showTitle()', in de module kitlvTdm, zoekt de volledige titels bij deze documentcodes. Die titels worden gehaald uit het bestand 'metadata.csv', dat te vinden is in de verzameling documenten van de Master "Soldaat in Indonesië".

# %%
# Hier specificeer je de map ("dir") waar de corpus staat, de searchterm en hoe veel woorden om zoekterm je terug wilt krijgen (window)
dir = '../toy_corpus' 
search_term = 'baboe'
window = 10

# Voor ieder bestand in de dir
for file in os.listdir( dir ):

    # Kijk of het bestand een "txt" is, oftewel een tekst bestand. Zo niet, probeer het volgende bestand. Anders: 
    if re.search( '[.]txt$' , file ):
        
        # Open het boek.
        book = open( join( dir , file ), encoding = 'utf-8' )
        
        # Zoek naar de search_term die hierboven is gekozen in de tekst. Als die gevonden is:
        if re.search( search_term , book.read() , re.IGNORECASE):
            
            # Sla de titel van het boek op in de variabele titel
            title = showTitle(file)
            
            # zoek voor de concordantie(s) en sla ze op in de variabele "matches".
            matches = concordance( join( dir , file ) , search_term , window )
            
            # Als er matches gevonden zijn:
            if len(matches)>1:
                
                # Laat de titel en de naam van het bestand (boek) zien
                print( '\n\nOccurrences in {} ({}):\n'.format( title , file ) )
                
                # voor iedere concordantie in de gevonden concordanties
                for match in matches:
                    
                    # Laat de matches zien
                    print(match)
# Out:
# Occurrences in De vergeten dagboeken (03392.txt):
#
# van aarden en krijg een hele preek mee isan onze baboe staat ons na te wuiven tot we geheel uit het
# mooie benen van elly en etty en lachen naar de baboes die ons lekkere dingen uit de keuken brengen en zelfs
# wakker maar liggen nog in bed zo ook mina de baboe 21e lacht verleidelijk tegen mij de deken gooit ze weg
# natuurlijk weer heerlijk was bespreken we de mogelijkheden om een baboe te krijgen dick heeft natuurlijk weer geweldige plannen en beloften
# kletsen hij zal zorgen dat er binnen het uur een baboe komt ik sta er sceptisch tegenover
# zijn maakt de tafel schoon in één woord een model baboe donderdag 6 februari 1947 tjikalon koelong ik ben vrij en
# de jongens zijn aan het stoeien met de baboe van hier naast eerst laat ik ze hun gang gaan
# het genoeg geweest is onder veel protest stuur ik de baboe naar haar eigen huis maar het blijft nog lang rumoerig
# zwaaiend naar oda mimi tina en hoe al die andere baboe s nog mogen heten vaarwel tjiranjang alweer een episode van
# met de derde compagnie zouden meegaan ik had aan die baboe nog wel gevraagd waar ze woonde maar ik heb alleen
# page 279 jan en kroontje zijn met itje de baboe van de verbindingspost een eindje de kampong in geweest ze
# het was echter te ver zodat ze teruggegaan zijn de baboe lacht hun uit
# al onder de klamboe lig zie ik dat kees onze baboe onna mee neemt onder de klamboe hij doet of het
# je welste dan komt er een heel gedonder over de baboes eerst willen ze alle twee bij ons in de weap
# ons in de weap dan komt van rundberg met de baboe van de v.p die moet ook in de weap daarna
# in de weap daarna komt de telefoonsectie vragen of hun baboe ook in de weap mag enfin het is een gekkenhuis
# het is een gekkenhuis en op het eind moeten alle baboes in een drietonner maar dan komt kees de chauffeur van
# ze ligt op bed en is een beetje overspannen en baboe is er vandaag niet goed dan kom ik morgen wel
# al gauw een 15 wght met een heel stel baboes een leuk ritje naar tjimelakka jammer dat het maar vijf
# ga ik verder de kampong in en vraag naar een baboe die voor ons wil werken maar de mensen zijn nog
# terug en ik spreek af met het grietje dat de baboe om twee uur bij haar huis zal zijn het grietje
# troep van die schoffies voor de deur ze hebben een baboe ik loop mee drie huizen verder staat het wonder ze
# is het niet een schoonheid evenmin maar we hebben een baboe vrijdag 27 februari 1948 telaga
# ik weer bij aangewezen het huis geen man en geen baboe te zien woensdag 3 maart 1948 telaga
# het werk en de boel knapt reusachtig op met deze baboe zal het wel gaan ze blijkt vroeger als baboe in
# deze baboe zal het wel gaan ze blijkt vroeger als baboe in bandoeng gewerkt te hebben en spreekt zelfs een beetje
# we worden begroet door genie koos en de baboes onna en roekia die echt blij zijn dat de toeans
# kees dat hij hem vannacht in het hok achter de baboes gegooid heeft omdat hij zo schreeuwde ik vind het katje
# we worden ontvangen als ere-gasten krijgen thee en koek de baboes van de verbinding hebben ook een ere plaatsje en worden
#
#
# Occurrences in Herinneringen van een Roodborstje : verhalen uit de periode 1947-1950 doorgebracht bij het 4e bataljon 5e Regiment Infanterie op Oost-Java in het voormalige Nederlands Oost-Indie? (03394.txt):
#
# bruiloftsstoet 21 10 geestelijk leven 23 11 buitenstaander 25 12 baboe 27 12 aapje 30 13 delicatesse 34 14 heterdaad 36
# de eerste verbazing iaar was bekomen besefte ik dat mijn baboe mij voor een soort stiekeme pedofiel hield vrij zeker tot
# bij elkaar zat de onderofficier vertelde mij dat dit de baboes waren die waren de aangesteld voor het wassen van de
# de post had bezet per tien soldaten was organiek één baboe beschikbaar zon n p baboe was in de voeding bij
# tien soldaten was organiek één baboe beschikbaar zon n p baboe was in de voeding bij de troep en werd voor
# die zegt dat ze graag baboe bij de soldaten wil worden hoe moet ik daarmee 8e
# 8e aan als omdat tom dwars alle zaken regelde betreffende baboes en djongossen nam hij ien het gesprek over laat ze
# niet goedkope sarong en dito kanten kabaja terwijl al onze baboes op len blote voeten liepen droeg zij met gratie een
# haar dat ons onderdeel voorzien was van het organieke aantal baboes en dat hij haar dus niet mocht aannemen ze was
# surabaya stond in de bijgebouwtjes achter deze panden vonden de baboes onderdak eén en ander voor zover deze dames niet in
#
#
# Occurrences in Als de natuur zwijgt (1945) (03396.txt):
#
# wassen is niet meer nodig de meeste secties hebben een baboe die voor hen dagelijks de kleren wast en strijkt strijken
# wassen is niet meer nodig de meeste secties hebben een baboe die voor hen dagelijks de kleren wast en strijkt strijken
# naar ons roepen tabeh toean zit me daar warempel onze sectiebaboe op het balkon dagelijks komt ze onze kleren wassen en
# is een rustige omgeving en hopelijk vinden we hier een baboe voor onze was ondanks al dat primitieve gedoe krijgen ze
#
#
# Occurrences in Op de plaats rust (03398.txt):
#
# m m mm wij konden het goed vinden met onze baboes voor een geliefd decor de sierlijke palmboom poseerden zij met
# wat zouden dan die meisjes kijken nu kijkt zelfs de baboe niet stel je voor dat ons majoortje s morgens vroeg
#
#
# Occurrences in Voor ik het nooit vergeet : herinneringen van een 4-2 R.I'er op Noord-Sumatra : gebaseerd op dagboekaantekeningen over de periode van 7 november 1946 tot en met 24 februari 1950 (03400.txt):
#
# het ogenblik ringworm en rode hond het jeukt ontzettend de baboe is net op bezoek geweest en het kleine chinese meisje
# met het uitdelen van rijst en katoen aan de honderdvijftig baboes en koelies van ons bataljon krentenbrood vandaag wel lekker maar
# page 77 talen aan de baboes en koelies druk dus er is een grote actie ingezet
# er elke dag wel acht soldaten hebben recht op één baboe voor de een complete verschoning van ondergoed tot was en
# frans probleempje even is het stil ik hoor buiten de baboe schuifelen over de pendopo ze komt de vuile was ophalen
# naar bindjei rijst halen om uit te delen aan de baboes stukje voor de gong geschreven 14 augustus 1948 weer wat
# in één keer geslacht gebraden en opgediend door onze onvolprezen baboe marianne omdat de schaal zo hoog was opgeladen met kippenboutjes
# de baboe en de djongos waren ervan overtuigd dat het een civetkat
#
#
# Occurrences in IndonesiÃ« op het tweede gezicht : een laat weerzien met terugblikken naar toen (03404.txt):
#
# ook nadrukkelijk de vraag op wat gebeurt er met de baboe en de djongos ais wij verdwenen zijn hoe zal hun
# wind atap soort dakbedekking atas semua voor alles babi varken baboe babu hulp in de huishouding baik goed gunstig bajar membajar
#
#
# Occurrences in 50 jaar na dato,' 1946-1996 (03405.txt):
#
# 7 page 10 baboe en de djongos wie heeft ze niet gehad en wie
# ze niet gehad en wie heeft ze niet gekend jje baboe en de djongos die werkten voor een krent wat had
# de djongos die werkten voor een krent wat had zon baboe het moeilijk en zwaar ioe kreeg en hield ze al
# 3apoen dat moest de baboe hebben voor het wassen jo hurkte ze aan de kali
#
#
# Occurrences in Thuisreis van het 3e bataljon Stoottroepen met het M.S. Kota-Inten, Tandjong-Priok/Rotterdam (03409.txt):
#
# van inladen is daar een laatste groet aan de vertrouwde baboes en djonggossen en aan de kampongbevolking die aan weerszijden van
# 4e compie page 46 page 47 woordvertalina patria kampong toekankajoe baboe djongos havengoedang koelie mandoer teng-teng kretek tampat passar kalie k.n.i.l
#
#
# Occurrences in Militaire politie in Nederlands-IndiÃ« 1945-1951 (03410.txt):
#
# burgerpersoneel dat ten behoeve van het detachement diensten verrichtte als baboe-tjoetji wasvrouw en koki kokki
# uitrusting meestal uitgevoerd in onderkleding deze werd dagelijks door de wasbaboes één baboe verzorgde zes man gereinigd teneinde verwisseling van de
# uitgevoerd in onderkleding deze werd dagelijks door de wasbaboes één baboe verzorgde zes man gereinigd teneinde verwisseling van de te wassen
# gemerkt met zo mogelijk onuitwisbare inkt dit leverde voor de baboes veelal analfabeet geen problemen op
# het burgerpersoneel zoals de baboes djongossen koks technischen administratief personeel stond bloot aan bedreigingen met
#
#
# Occurrences in De Indie?gangers : over de in de jaren 1945-1950 uit Hardinxveld en Giessendam uitgezonden militairen in de oorlog met de Republiek Indonesie? (03411.txt):
#
# van geestelijke en sexuele aard de inlandse vrouwen vooral de wasbaboes in de kazernes zijn een gevaar de ontspanning die de
# zoals mannen die de vrachtwagens laadden en losten en de baboes met zes man hadden we een baboe voor het opruimen
# losten en de baboes met zes man hadden we een baboe voor het opruimen van de kamers wassen strijken en dergelijke
# inlandse bevolking had je behalve met het eigen personeel zoals baboes en djongossen weinig contact maar als ik onderweg in een
# aanen afvoer troepen arp anti-revolutionaire partij bahasa indonesia indonesische taal baboe vrouwelijke indonesische huisbediende of wasvrouw belanda nederlander
# Occurrences in Herinneringen = Memoirs (03414.txt):
#
# ik vond al vlug een geschikte baboe die ons trouw gediend heeft tot de dag dat ze
# holland with his family i knew he had brought a baboe with him from java so i went to enquire there
#
#
# Occurrences in De wedergeboorte van het Vliegveld Pakan Baroe tijdens en na de tweede politionele actie (03415.txt):
#
# dan 8 man we hadden dus nu recht op een baboe
# optocht van drums rollende militairen djongossen burgers en zelfs de baboe hielp mee het halen van de benzinedrums was gemakkelijk het
# en haar kinderen die onmiddellijk bezit namen van hun roema baboe waarop voor eenmaal de nederlandse vlag stond
# we hadden het met onze baboe goed getroffen ze was goed in alles wat een huishoudelijke
# 9r|be subs i ssssssk me m jggst fa voor onze baboe kwam nog een verrassing op de een of andere manier
# de auto onze mandoer de dochter van ah min onze baboe boeng de trouwe djongos en jim beudeker op het bord
#
#
# Occurrences in De grote patrouille : belevenissen van het bataljon 5-4 R.I. in Zuid- en Oost-Borneo, Zuid-Sumatra en Oost-Java in de jaren 1947, 1948, 1949, 1950 (03416.txt):
#
# in de huishouding hebben ze niet veel te doen de baboe zorgt voor de was de kokkie voor het eten en
# alang-alang hoog rietachtig gras b.b binnenlands bestuur bat bataljon baboe dienstmeid of wasvrouw beland hollander sren lichte mitrailleur break down
#
#
# Occurrences in En weer werd de vijand verslagen' : dagboek Hein Peeters, Tjipanas 21 juli 1947 : de Baarlose jongens in Indie? 1945-1950 (03417.txt):
#
# bar slecht we hebben al twee maanden honger geleden de baboes hebben gestaakt omdat ze geen geld meer krijgen de betaalmeester
# inschrijvingsregisters en dienstplichtkaarten ongeordend 321 1865 page 174 verklarende woordenlijst baboe belanda demarcatielijn dessa extremist goenoeng kali kampong klamboe loerah pasar
#
#
# Occurrences in Levenslang op patrouille (1946) (03418.txt):
#
# radio hadden wij niet t.v bestond nog niet de baboes deden de was de kokkis kookten voor ons de djongossen
# page 31 iedereen was op zijn qui-vive de baboes en djongossen hadden we op hun verzoek meegenomen en die
# met aardige meisjes het was wel wat anders dan de baboes van sapuran
# echter geen woord javaans verstond nam ik als tolk mijn was-baboe asmina mee na afloop van de bespreking ging ik met
# geen kleren had antwoordde ik helemaal voor niets vroeg de baboe verbijsterd
# meisje in mijn onnozelheid antwoordde ik bevestigend nu wist de baboe genoeg in het bijzijn van het kind en van mij
# van de verbazing bekomen was besefte ik pas dat mijn baboe mij voor een soort pedofiel hield ze was teleurgesteld toen
#
#
# Occurrences in Hallo, hallo, hier zijn we weer ... : Henk Wieringa in Nederlands-Indie? (1946-1949) (03419.txt):
#
# maar niet meer we hebben hier met 5 man een baboe s morgens om half acht staat ze al bij je
# enz net een bajes zon gevoel heb je dan de baboe is eventjes water halen het druist regelrecht tegen je principes
# 03 vanmorgen lag ik nog in bed toen had de baboe minie heet ze al brood en thee voor me gehaald
# schei er uit want ik moet inspectie houden onder de baboes want ze hebben de gewoonte om onze handdoeken om dr
# ik heb soms de lelijke gewoonte om tegen minie mn baboe een vloek te uiten dan vraagt ze met een bedroefd
# surinamers werden met revolvers neergelegd we hebben ook een nieuwe baboe want de oude beviel ons niet meer de nieuwe heet
# een flesje ijskoud lion bier voor me buiten zijn de baboes aan het zingen of liever gezegd aan het huilen ze
# geslapen hoor de zaaik draait intussen al weer huriy-up de baboes staan al weer op de kop in het water te
#
#
# Occurrences in Zeemilicien bij de Mariniersbrigade (03420.txt):
#
# dan ook danig van lang als hij een opmerking richting baboe of andere vrouw maakte we hebben hem zelfs diverse malen
# foto er één van een soort heilige slapen met de baboe het heeft geen zin te ontkennen dat er zo nu
# ontkennen dat er zo nu en dan ook met de baboes werd geslapen teneinde de sexuele driften enigszins te beteugelen dat
# man of meer waar de dokter of de ziekenverpleger de baboes eerst keurden
# marinier uitteketting dan riepen wij die is getrouwd met zijn baboe dat was wel niet zo leuk maar toch werd de
#
#
# Occurrences in Naar de Oost : oorlogsvrijwilligers naar Nederlands Indie? 1945-1948 (03421.txt):
#
# 2e baboee diepen in een gebouwtje aan de andene kant aan de
# meisjes van onze achterburen huilden tranen met tuiten en de baboes keken weemoedig daar gingen we dan na een verblijf van
#
#
# Occurrences in Gedenkboek oud-Indie?gangers gemeente Dalfsen 1945-1950 (03422.txt):
#
# 28 enige baboes werden bedreigd door peloppers omdat ze voor ons werkten maar
# soldaten maar ook meubelen en fietsen en tussen dat alles baboes en djongossen die graag meegingen naar ambarawa waar het grote
# werden de tafels met alles erop omgekeerd en kwamen de baboes binnen om de rommel bij elkaar te vegen met zeer
#
#
# Occurrences in De hemelse kwartiermaker : brieven van een jonge Maastrichtse oorlogsvrijwilliger aan zijn thuisfront, 1945-1947 (03423.txt):
#
# totaal 2 97 1 st zoutwater-zeep gratis wm liffiéö pr baboes aan de was juli 1947
# later wel we slapen met vijven in n hut de baboe haalt iedere morgen de was weg en brengt ze s
#
#
# Occurrences in Na vijftig jaar : dagboekherinneringen van een soldaat in Indie?, 1949-1950 (03427.txt):
#
# liggen zei hij later iedereen ging gauw mandiën en de baboes maakten de geweren schoon
# toegevoegd hij is een stuk ouder vrijgezel hij heeft een baboe voor zich alleen wij met zijn allen hebben we organiek
# zich alleen wij met zijn allen hebben we organiek een baboe per 8 of 10 man alleen voor de was en
# brand arm volk page 42 siti iffl wnh hl onze baboe van het peloton siti was onze baboe in probolinggo was
# wnh hl onze baboe van het peloton siti was onze baboe in probolinggo was ze in dienst van ons peloton gekomen
# brandende houtskool erin arang behalve siti hadden we nog meer baboes maar de namen zijn me ontschoten siti was de hoofdbaboe
# baboes maar de namen zijn me ontschoten siti was de hoofdbaboe we hadden per 8 man een baboe ze hielpen ook
# siti was de hoofdbaboe we hadden per 8 man een baboe ze hielpen ook de kok en maakten de kamers schoon
# zou nooit meer wennen in de burgermaatschappij als theeplukster of baboe bij een planter
# als er onverhoopt een jongen verliefd werd op een baboe zorgde siti dat er een eind aankwam in het ergste
# er een eind aankwam in het ergste geval werd de baboe weggestuurd siti bleef tot op het laatst trouw aan ons
#
#
# Occurrences in 2046 : 7de A.A.T. Compagnie O.V.W.-ers (03428.txt):
#
# nog maar eens om en.de deur ging open en vier baboes kwamen sloffend naar binnen en beginnen ijverig brood klaar te
# opmerking van ijdhun 24 uur gelukkig voor hun nokken de baboes af voor de de meesten was de slaap over en
# was een goede 30 km en het lag halverwege de merbaboe een 3142 meter hoge berg aha zeiden we vanavond zijn
# de tijd toen wij pas in indië gearriveerd waren met baboes die zich in de kali bevonden en daar kleren aan
#
#
# Occurrences in "Soldaat E. Kerkdijk : registratienummer 25.12.12.159 (03429.txt):
#
# soedanezen mohammedaans zijn en zodoende de meeste koelies djongossen en baboes niet werkten en tevens omdat het de laatste dag was
# dat er iets in de lucht hangt hebben zelfs de baboes en de djongossen in de gaten en die zijn nog
# met een colonne van 7 wagens 5 wagens met meubilair baboes djongossen enz enz en de andere 2 zaten wij op
# op natuurlijke wijze overleden bij vertrek van post tjibaroesa staan baboes djongossen te gillen te wuiven wij laten kisten maken voor
#
#
# Occurrences in Portret mozaik spandrich Bonnet : Belanda - Indonesia - Belanda = Portret in mozaiek van soldaat 1e klas Kees Bonnet : Nederland - Indonesie - Nederland. (03430.txt):
#
# 47 wsbm wêsm mam v probolinggo rond de waterput de baboes doende met de was jfei ipf^i r m i links
# bamhoom was laat op hij had ook wacht gehad de baboe was nog op de kamer jan nog in zijn pyjama
# rekte zich behaaglijk uit en maakte een grap met de baboe hij sprak immers zo goed maleisnam de baboe in zijn
# met de baboe hij sprak immers zo goed maleisnam de baboe in zijn armen en drukte haar stevig tegen zich aan
# in de schaduw van de grote bomen jmm êëm de baboes twee worden omarmd door kees page 57 na zon lange
# grote huis was ingenomen ik kreeg een badhokje toegewezen de baboe kwam naar mij toe en vroeg waar slapen jouw bed
# slapen jouw bed ik wees naar mijn privékamer een andere baboe kwam ook aan mij vragen waar slapen jouw bed ik
# waar slapen jouw bed ik zei dat ik al een baboe had de twee baboes kregen ruzie om mij daar bemoeide
# ik zei dat ik al een baboe had de twee baboes kregen ruzie om mij daar bemoeide ik me niet mee
# de baboe helpen op een morgen zat ik wat verveeld in de
# ik wat verveeld in de grote kamer eén van de baboeszij was nog niet zo lang bij onswas een magere wat
# moeilijk omdat we de hulp moesten inroepen van de andere baboes wanneer wij haar wat wilden vragen kwam zij van madoera
# aan de andere kant van de kamer te vegen de baboe keek even op zij zag mij ook vegen gooide haar
# neer en liep gillend hysterisch huilend weg met een andere baboe kwam zij terug waarom toean kees zeggen zij viespeuk ik
# de aap van freek schoolenberg 41 de apen 21 de baboe helpen 24 de bedden 13 de duif 38 de familie
# Occurrences in De rijst is al pap geworden : Indie?-veteranen vertellen hun verhaal (03433.txt):
#
# rustig winkelen ilf if 11111 erffin page 21 m*r 13 baboes doen de was 14 aardappelen schillen in de tropen page
# wij hadden als soldaten bedienden ter beschikking meest jonge vrouwen baboes en jonge mannen djongossen zij deden voor ons de was
# met mijn baboe santani ging het niet zo goed ik zei tegen een
# sommige jongens leefden met hun baboe als getrouwde stellen page 108 in pasoeroean ging een van
# getrouwde stellen page 108 in pasoeroean ging een van de baboes naar tjermee ik vroeg haar of ze wilde informeren naar
# santani gevonden santani zelf heeft een moeilijk leven gehad als baboe voor de hollanders werken was nog net acceptabel maar een
#
#
# Occurrences in Mijn leven : autobiografie (03435.txt):
#
# hoefde we nu zelf niet te doen daar hadden ze baboes voor javaanse meisjes die dat werk deden zij werden door
# schrijven kon toch af en toe een brieije schreef onze baboes werkten goe je had hier veel kleding nodig want je
# hoorde daar ook bij alles ging gewoon zijn gang onze baboes vonden er ook niets aan dat wij weg gingen want
# te drinken gebracht er liepen wel een stuk of tien baboes rond daarna was er nog wat te eten daar was
#
#
# Occurrences in De laatste patrouille' : episode 1946-1950, Midden-Java (03437.txt):
#
# mijn zijde het mooiste meisje wat er maar zijn kon.(alle baboe gezichten verbleekten hierbij verdomme jammer dat ik wakker werd die
# luierde sliep lang keek wat meer naar de mooie slanke baboes en nam me voor weer aktief te worden op ander
# en blies de rook in kringen omhoog zullen we onze baboe vragen of ze zich uitkleed voor ons hij keek me
# genoeg in de kampongs om ons heen."we vragen of onze baboe hem niet een paar nachten onder haar hoede wil nemen
# terug scharrelde links en rechts een beetje met een mooie baboe en genoten zelfs van deze troebele tijd aalmoezeniers kwamen en
#
#
# Occurrences in Dikke zoen voor Moeke : brieven van een soldaat in IndiÃ« 1949-1950 (03438.txt):
#
# kasten stoelen enz plus twee grammofoons met banjak platen twee baboes doen de was en we hebben een djongos voor allerlei
# we hebben een stel baboes die zijn allemaal stapelgek geloof ik want het ene ogenblik
# door de peloppers vermoord fraaie lui hoor nu durven de baboes niet meer van de post af te komen lieve moeke
# ze alle bussen en pannetjes worden als trommels gebruikt de baboe zegt tegen me banjak nakal itoe toean wat betekent de
# stoelen achter elkaar en de voorste met een bel de baboes hebben zich een stuip gelachen maar ja we hadden ook
# pt ui ik w im wat moet ik al die baboes laten doen wmm i veldbed klamboe tampalje page 95 onze
# bangil 19-11-1949 al vroeg moest ik lachen om de baboe die we mee hadden genomen vanuit plaosan en die voor
# hele kamp is in rust ik ben wasbaas van de baboes maar ik geloof het wel ze kunnen zonder mij ook
# nodig ik kan dat pak zo inleveren voor nieuw de baboe denkt dat we steeds kleren zelf moeten betalen als dat
# de deur in huis gisteren zondag zijn twee van onze baboes er vandoor gegaan met al het wasgoed plus twee stens
# één van de weinigen die zelfs geen puistje heeft die baboes rinum en astana die ervan door zijn werkten al 12
# van der put page 158 woordenlijst aloon2 stadsplein anak2 kinderen baboeshuisof kindermeid banjak veel barang bagage spullen blanda blanke bokketuig uniformriemen
#
#
# Occurrences in 432 - B.I. opdat wij niet vergeten 7 - 1 R.I. (03439.txt):
#
# ginds ligt de kampong van onze baboe ook daar blijft het doods en stil een stukje indië
# terug naar de kamer dankzij de goede zorgen van een baboe kan ik iedere dag beschikken over schoon ondergoed en bovenkleding
# wassende baboes zo nu nog mijn lage bruine schoenen aangetrokken en ik
# maar hier lijkt het er meer op of wij de baboe van het volk zijn wij kunnen alles voor ze opknappen
# uit nantes hij stond er te strijken als de beste baboe die we ooit in het land daar achter ons hadden
#
#
# Occurrences in Spinninghe : Sevenumse Indie?gangers, de vleegende Piee?lhaas (03440.txt):
#
# aloon aloon groot plein plaats)namen veranderd b.v links oude benaming baboe bandjir vrouwelijke bediende overstroming borneo kalimantan barang bagage celebes sulawesi
# toen bleven er nog vier zij bespraken alles met de baboes der compie een der baboes gaf het door aan de
# zij bespraken alles met de baboes der compie een der baboes gaf het door aan de t.n.i dit is de moraal
# iedereen vrij om te doen waar hij zin in heeft baboes maken de bedden op met lakens en slopen en houden
# alles in goud of iets dergelijks omgezet de arme tani baboe en djongos is weer de dupe zij hebben amper geld
# soorten zweren heeft hij een hele bus zalf als de baboe zich in de vingers gesneden heeft heeft piet ook nog
# en dan de baboes nu jongens op dat gebied moet ik jullie teleurstellen baboes
# baboes nu jongens op dat gebied moet ik jullie teleurstellen baboes zijn er hier niet alleen maar flinke grieten lieske heeft
#
#
# Occurrences in Logboek 1-41 RVA : verhalen en wetenswaardigheden (03441.txt):
#
# b1 of misschien zelfs al een c1 bericht als de baboe in de kampong iets had gehoord van de sate-verkoper werd
# en wapens en munitie halen ons wasgoed wordt verzorgd door baboes die wassen en verstellen
#
#
# Occurrences in Voor orde en vrede (03444.txt):
#
# al na drie minuten radiomuziek hadden er is daar zon baboetje dat één en al zorgzaamheid is
# gezellig onder de galerij te eten bediend door de onvolprezen baboe vogelaar haalde een blik boter in de stad zodat we
# op een uitgestrekte vlakte in het westen waren de vulkanen merbaboe en merapi te zien in het oosten de larere water
# djongos huisjongen kardja en baboe sitie dit waren onze verzorgers voor eten en kleding te
# dankbaarheid vervult zijn hart hij denkt ook aan de trouwe baboes koelies en djongos vaak zeiden ze hoe zal het zijn
# rust dus slapen wat dan ook wel nodig is de baboes wassen en strijken voor ons dus iedere dag schoon goed
#
#
# Occurrences in Twee maal oorlog : ervaringen van de Indie?-veteranen uit de gemeente Bemmel die na de Tweede Wereldoorlog werden uitgezonden naar het toenmalige Nederlands Oost Indie? (03446.txt):
#
# burgerpersoneel voor het huishoudelijke werk is inlands personeel koelies en baboes aangetrokken de bewaking vindt plaats door inlandse jonge militairen het
# moet doen ik kom daardoor in een bevoorrechte positie een baboe voor de was en een djongos voor het onderhoud van
# inmiddels hebben wij enkele baboes ingehuurd om het huishoudelijke werk te doen een van de
# vrachtwagens voorrijden er is een hartelijk afscheid van de javaanse baboes en djongos pietje en mina zouden aanvankelijk door de commandant
# met daarbij de onmisbare klamboe er wordt medegedeeld dat vrouwen wasbaboes zijn aangesteld om de kleding te verzorgen ergo alle wasgoed
# we nemen afscheid van vrienden en kennissen de djongos de baboes met vrachtwagens rijden we naar de haven van priok in
# krijgen op kosten van de dienst per zes man een baboe toegewezen hun taak is de kleding te wassen en het
# wat moet gebeuren we besluiten voor eigen rekening het aantal baboes zodanig uit te breiden dat iedere man van ons peleton
# te breiden dat iedere man van ons peleton een eigen baboe heeft we bieden kost en inwoning aan door ze mee
# we met de staf van het regiment naar madioen de baboes hebben het bij ons zo goed dat ze meeverhuizen naar
# onmisbaar attribuut slaapklaar erboven opgehangen de afwas geselecteerd voor de baboes
# gebracht we worden voorlopig ondergebracht in een grote loods waar baboes de gelegenheid krijgen de was te verzorgen voordat we verder
#
#
# Occurrences in Uust me? (03447.txt):
#
# plaats van verdediging aan en een beschutte plek voor de baboes met een kist patronen tegenover purwodadi aan de overkant van
# snel handelend beveel ik de baboe deze mensen te verzorgen en snel naar de militaire post
# meld je maar bij de baboe zeg ik zij zal je wel aan het werk zetten
# volgens opdracht verwent de baboe het moedertje uit de verre kampong en ze mag de
# morgen terug naar haar kampong op een morgen komt de baboe mijn verzorgster naar mij toe tuan zegt ze u bent
#
#
# Occurrences in Kempische militairen in de Oost : herinneringen aan Nederlands-Indie? en Nieuw-Guinea (03448.txt):
#
# van de bezwete kleren te ontdoen die direct naar de baboe gingen ondertussen konden we even lekker mandiën dat gebeurde in
# ik heb dit aan de jongens doorgegeven en ook de baboe gevraagd te willen zorgen dat de kamer netjes in orde
# niet zonder ook een welgemeende terima kasi aan onze trouwe baboe
# mm-a n mm page 88 en dit zijn nu de baboes é*r mi isi a page 89 fcsgg 1 m éét"1
# pas op kijk uit babi varken babi panggang geroosterd varkensvlees baboe meid kindermeisje bagoes mooi bahasa taal barang bagage barangkali misschien
# Occurrences in De Haantjes in vogelvlucht : het Veluwebataljon I-8 R.I. in IndiÃ«, 1945-1948 (03450.txt):
#
# naar huis de uitgenodigde kampongbevolking en ons eigen personeel met baboes en djongossen genieten met volle teugen van het hollands-indische taaltje
# van een verscheurd tropenland het land van tanige tanis boenende baboes hete sawas en koele bergen
#
#
# Occurrences in 1-15 R.I. De Blijvertjes : onbewust voorloper van de Luchtmobiele Brigade (03454.txt):
#
# i.d post bodja ii door i.d post bodja werden de baboes en koelies van 3-1-15 r.i gescreend door de i.d te
# 3-1-15 r.i gescreend door de i.d te oengaran werden de baboes en koelies van de staf-cie 2 cie en een gedeelte
# zijn dit is ook de mening van de bevolking 2 baboes en 7 koelies gescreend voor 3-1-15 r.i ons inziens allen
# door i.d post bodja en deze screende tevens weer 3 baboes en 3 koelies allen geschikt
#
#
# Occurrences in IndiÃ« blijft ons bezighouden (03456.txt):
#
# een soldaat 49 brieven uit het veld 57 hoe een baboe een peloton soldaten redde 63 krantenberichten in 1948 en 40
# page 65 hoofdstuk 7 hoe een baboe een peloton soldaten redde het gebeurde in maart 1949 bij
# actie komen op die dag kwam er s middags een baboe naar hem toe hij kende haar wel want ze werkte
# t.n.i en wel diezelfde avond als hij wacht had de baboe die al jaren voor hollandse soldaten waste had zich echter
# de baboe bezwoer dat ze er nog met niemand over had gesproken
# terug naar huis beseften ze hoe dankbaar ze eigenlijk die baboe moesten zijn als die niet tijdig gewaarschuwd had zouden de
#
#
# Occurrences in Het 425e Bataljon Infanterie [I - VI] : [herinneringen aan de tropen ...] (03458.txt):
#
# zelfs de baboes begrijpen dat dergelijke orders niet uitvoerbaar zijn hij is altijd
# zelfs de baboes begrijpen dat dergelijke orders niet uitvoerbaar zijn hij is altijd
#
#
# Occurrences in Geliefde ouders en verdere familie! : brieven van IndiÃ«ganger Maarten Schaafsma (03460.txt):
#
# ln.r staand santani bleekman spiering gebogen ohms v.l.n.r zittend kronenberg baboe voskuyl baboe zittend vooraan baboe im"1 s ï 9 de
# santani bleekman spiering gebogen ohms v.l.n.r zittend kronenberg baboe voskuyl baboe zittend vooraan baboe im"1 s ï 9 de post keizersveer
# gebogen ohms v.l.n.r zittend kronenberg baboe voskuyl baboe zittend vooraan baboe im"1 s ï 9 de post keizersveer bij de kali
# en ik vertelde niet hoe verliefd ik was op mijn baboe santani maar er bleef genoeg over om wel te schrijven
# tot weerziens uw maarten baboe santani en haar neefje mat in de kazernes van het
# eenzame posten ver van de bewoonde wereld daar was de baboe een onontbeerlijke hulp
# ook dim al gauw was zij de baas over alle baboes en ze leerde ook verrassend snel zich verstaanbaar te maken
# waterwagen werd aangevoerd bij de ene groep vaten deden de baboes de was en daar stonden ook een paar lange tafels
# mandihok en toen ik naar binnen scheen zag ik vier baboes die zich aan het wassen waren ze gilden luidkeels en
# hij begon als volgt jullie zult al wel van je baboe vernomen hebben dat wij aanstaande donderdag naar grissee verhuizen dat
# daarop stonden vier gedeeltelijk stenen kamponghuizen waarin wij met de baboes gelegerd waren rond de kampong was zoals gewoonlijk een dichte
# wist er weer bruikbare soldaten van te maken ook de baboes waren doodsbang en zochten bij ons in de kamponghuizen bescherming
# dank daarvoor gaf hij ons een paar kilo oebie de baboes bereidden dit en het bleek goed eetbaar het smaakte een
#
#
# Occurrences in He-j doar nog vocht'n? : herinneringen aan zijn tijd in Nederlands-Indie? (03462.txt):
#
# ik kreeg ook de opdracht toe te zien op de baboes iets verderop die belast waren met het wassen van de
# page 35 vijf personen de kleding aan de baboe mee kunnen geven en had men de besmetting veel beter
# voor andere pleziertjes kon zorgen tevens was er een setenga baboe in goed nederlands gezegd een daghitje
# zijn kompas er een flink eind naast heeft gezeten de baboes zullen het de volgende dag ook niet gemakkelijk hebben gehad
# ineengedoken een zielig hoopje mens ik vergeet nooit hoe onze baboe daarop reageerde la ilah itoeh toean sapi in het nederlands
# acties werd altijd s avonds de route bekendgemaakt wanneer de baboes en djongos al lang naar de kampong waren er werd
# was de pasjes van het inlands personeel controleren djongossen en baboes dus uit pure pesterij draaide hij de zaak om juist
# in gebroken pasarmaleis naar een pas als de koelies en baboes daarentegen hun pas wilden tonen dan was het van rot
# s m.i sakith sapi sawa sawatrapper sepulu orang mati setenga baboe sirihpruim soesoe manis t n.i tahoen jang soedah loepade tampatje
#
#
# Occurrences in Uit het marineleven gegrepen (1945) (03465.txt):
#
# op de foto boven samen met de bottelier tussen de wasbaboes in de marinekazerne twee wageningers in marinekazerne weltevreden een slordige
# bij een walplaatsing had men de beschikking over wasbaboes voor een redelijke vergoeding reinigde steef en streken zij je
# was s morgens direct na overal altijd een wat oudere baboe aanwezig zij had toestemming om het terrein te betreden haar
#
#
# Occurrences in Respect en erkenning : veteranen Schaijk-Reek in Nederlands-Indie? 1945-1950 (03467.txt):
#
# naar semarang zouden gaan tot ieders grote verrassing vroegen de baboes of zij naar djogjakarta zouden gaan het antwoord was nee
# zomer 1949 voor de vijandelijke aanval theo samen met de baboe op de pasar inkopen doen van rietsuiker en ananas page
# van de vijand op weg naar de top van de merbaboe jan schouten eerste van links onze eerste verblijfplaats was groots
# gingen we een keer met een gewapend patrouille de berg merbaboe op
# de veren dan werd ik gewekt door een van de baboes die bij mij werkte er was niet veel keus in
# en bang voor de dag van morgen inlandse vrouwen de baboes haalden de messtins op messtins de voerbakjes van de soldaten
# de messtins op messtins de voerbakjes van de soldaten de baboes brachten het eten de eerste indië maaltijd lieve bedeesde vrouwtjes
# de bak werd gevuld door n djongos knechtje of n baboe wasvrouwtje we hoorden doffe dreunen en er kermde een dier
# grasveld hoog scherp rietgras kind volgeling rivier wacht bij vuur baboe bale bale baroe bawan belanda besar betjak huishoudelijke hulp rustbank
#
#
# Occurrences in IndiÃ« vergeet je nooit! (1945) (03468.txt):
#
# een ander boeiend verhaal is dat van de baboe die een peloton soldaten redde in dit verhaal komen wat
# het verraad van de nederlandse militair het verraad van de baboe alleen al vanwege dit verhaal is het boek zijn aanschafprijs
#
#
# Occurrences in Wij van de 4e Hulpverbandplaats Afdeling : herdenkingsboek van de 4e Hp.V.A. (03471.txt):
#
# gij zult u niet ophouden op de galerij waar de baboes staan ter strijking noch in het waslokaal waar zij staan
# dat kan zó toch nóóit bestaan die wagen moet fourageren baboes halen en zo meer op één dag drie-honderd mijlen is
# zong ik haast in wanhoop het al maanden oud refrein baboe awas pigimana tida boleh masoek toch ojoh djongos maoe apa
#
#
# Occurrences in Op vleugels in hoger sferen : een vliegers-odyssee (03476.txt):
#
# page 17 jeugd mijn vroegste herinneringen gaan naar baboe toe-eh zij was klein had vele jaren achter de rug
# grote blonde man met handen als kolenschoppen die desgevraagd zei baboe toe-eh kan vijftig zijn maar als ik die rimpels van
# hoe dan ook baboe toe-eh zorgde voor me alsof ik haar eigen kind was
# en ik zei dat dat een tjatjing was verbijsterd keek baboe toe-eh me aan en riep dat dat geen tjatjing was
# centraal burgerlijk ziekenhuis waaraan een militaire vleugel was verbonden van baboe toe-eh leerde ik dat dat een roemah sakit was baboe
# baboe toe-eh leerde ik dat dat een roemah sakit was baboe toe-eh probeerde me uit te leggen waarom er telkens mensen
# me waardoor ik een soort gejuich deed horen dan trok baboe toe-eh me aan mijn arm fronste haar gerimpelde gezicht en
# soms wat langer op de plee te blijven soms bracht baboe toe-eh me naar de buren waar een jongetje was van
# we in de tuin spelen onder het toeziend oog van baboe toe-eh en haar evenknie de baboe van het jongetje
# het toeziend oog van baboe toe-eh en haar evenknie de baboe van het jongetje
# baboe toe-eh zorgde ook voor mijn bijna drie jaar oudere broer
# uitlopen mijn zuster was dan mijn reddende engel die riep baboe toe-eh en die suste ons snel merkwaardig is wel dat
# in dat verband werd ook een waarschuwing gegeven dat de baboe ketips dubbeltjesdames die bij de poort stonden vele risicos gaven
# Occurrences in Onhoorbaar groeit de padi : front-soldaten in een verloren oorlog : Indonesie 1948-1950 (03478.txt):
#
# naar djating aleh een noordelijke hooggelegen buitenwijk van de stad baboe en djongos ze gedroegen zich zoals ik verwacht had
# een bijgebouwtje van ons kantoor verbleven sumira en tina onze baboes die voor het eten en de was zorgden het was
# geen paradijs maar toch ook het 403e bataljon infanterie het baboeprobleem elke morgen om een uur of zeven staat de baboe
# baboeprobleem elke morgen om een uur of zeven staat de baboe onze wandelende wasserij geduldig te wachten op het moment dat
# zijn we een stapje verder we weten nu dat de baboe strijken moet al stribbelt ze ook nog zo hard tegenf
# nog niet weten hoe ze zich ten opzichte van de baboe hebben te gedragen wanneer we vriendschappelijk zijn gekheid maken en
# gedragen en geen aanleiding geven tot intimiteiten dan zullen de baboes zich ook behoorlijk gedragen de lezer zou graag weten wie
#
#
# Occurrences in Indonesie? als eindstation : met het vergeten leger in Indie? (03479.txt):
#
# hebben we dagelijks de beschikking over een koelie en een baboe om de was te doen de bedden op te maken
# nico is belast met alles wat de koelies djongossen en baboes aangaat en als ik bij hem ga klagen dat onze
#
#
# Occurrences in Bij de inlichtingendienst op Midden-Java (03482.txt):
#
# in 1887 verscheen de eerste en enige nederlandse opium-roman baboe delima de oudofficier van het nederland-indische leger m.t.h perelaer noemt
# huishoudelijk problemen aan de orde zo had johan diender onze baboe naoemi meegenomen naar kaliwadas9307 en waar vind je een goede
# naoemi meegenomen naar kaliwadas9307 en waar vind je een goede baboe wel op proempang-0801 de heer blijham zou er voor zorgen
# alles met elkaar was er toch genoeg om ook de baboe s en de djongossen mee te kunnen laten eten heel
# het de gelegenheid om opnieuw afscheid te nemen van hun baboes en djongossen die op het perron stonden om ons nogmaals
# 214 adat ajam alang-alang aloen-aloen andjing nica arak assistent-wedana babah baboe badjoe bagian baleh-baleh bamboe roentjing bami goreng bandjir baoe baroe
#
#
# Occurrences in Nou, tabee dan, ik groet je... : wetenswaardigheden van een vijfjarig verblijf in IndiÃ« 1945-1949 (03486.txt):
#
# is wel eens ruzie officier van piket op sokken de baboe bij de kok afijn er zijn wel eens brokken
# ligamok gen plotseling onbesuisd gaan optreden toestand van razernij autonomie baboe baroe bbataljon batikdoek zelfbestuur vrouwelijke bediende dienstbode nieuweling een brigade
#
#
# Occurrences in De geschiedenis van de 5e Genie Veldcompagnie, 1946-1949 : Nederland - Engeland - Java (03487.txt):
#
# 57 eerste politionele aktie 79 aan de voet van de merbaboe 96 bersiap merdeka 115 aanvallen vrijheid dagboek van een 1ste
# khakiuniformen die gewassen of geperst waren door de alom geprezen baboes liepen ze dan rond op zoek naar koopjes naar pilsjes
# suikerriet per ossekar page 110 aan de voet van de merbaboe vanaf 31 juli 1947 lag de 5de genie veldcompagnie voortaan
# kennissen gingen eten veelal in de kampong bij die lieve baboe of djongos waarvan de laatste waarschijnlijk niet als echt lief
# pasar te gaan of om bijvoorbeeld te gaan werken als baboe djongos of anderszins
# exploderende vulkanen zoals die van de merapi en vroeger de merbaboe die nu gezien moet worden als een slapende vulkaan
# afscheid te nemen van de bedienden in buitenzorg van je baboe of djongos of van de resterende kennissen in batavia maar
#
#
# Occurrences in Den Dungen in Nederlandsch Oost-Indie?, 1946-1951 (03489.txt):
#
# met een vaak nadrukkelijk gebaar zal de soldaat tegenover baboes tegenover landbouwers tegenover de eenvoudige dessabevolking zo gewoon mogdijk doen
# liepen ue daarbij zelf in een hinderlaag.uat bleek namelijk onze baboes en koelies die ons zo goed verzorgden bleken zich in
# maar dat zal wel wennen.de vrouwen in indië heten allemaal baboe.zij wassen voor je en als je wilt doen ze nog
# dat weet u wel.pietwaar tante sibelia er zijn trouwens ook baboes die christelijk zijn.die stelen niet zoveel en die eten geen
# bureau inw dienst 6e cie.waarbij het noodzakelijk is de betreffende baboe mode te brengen 12 het terugbrengen van het wasgoed geschiedt
#
#
# Occurrences in 15e Genie Veld Compagnie : 30 juni 1947-29 juni 1950, geschiedenis van een dienstplichtig soldaat (03490.txt):
#
# wel aan de slag voor onszelf djongossen zijn hier niet baboes wel maar die mogen we niet hebben vanwege je weet
# s nachts is het niet koud deze keer hebben we baboes toegewezen gekregen om voor ons de was te doen en
#
#
# Occurrences in Duizend dagen IndiÃ« : het dagboek van Jan van Trigt 1945-1948 (03491.txt):
#
# gek bovendien dicht bij de keuken dat is wat waard baboes zijn al gauw op komen dagen vreemd is dat een
# netherlands forces intelligence service zit die ik aantref bij een baboe in bed ik schrik ervan maar praat met hem over
# gevangenen broer bolk doet zijn best hij geeft aan de baboe een sjaaltje dat voor hem dienst deed als shirtje zon
# bezems aan de zijr kanten we nemen afscheid van de baboes en djongossen die we hartelijk danken voor al het werk
# ik dan maar door ze te vertellen dat er 22 baboes meegekomen zijn i.p.v post wie gelooft dat 151
# balken voor de deuren interne veiligheid we kunnen be de baboes niet vertrouwen broer gaat naar batavia een kookcursus volgen niet
# sgt hermans schiet een chinees kapot en t uit een baboe door haar kin bij het schoonmaken van zijn karabijn zal
# boven wonder wat sloten gekomen van de verplegingsofficier de ge baboes zien lijdelijk toe je kunt het ze aanzien dat ze
# groenhart gaat wel die heeft toch niets te verliezen de baboe is opgepikt door n de politie zal wel niet zo
# batavia stuurden het als beloning voor mijn stukje b ovet baboes in de wapenbroeders komt heel goed van pas
# momenteel zitten we zonder djongos of baboe maar kleren toch gewassen want er lopen er nog genoeg
# van de jongens naar baboes de bezoeken aan de kampong worden drukker en drukker er
# de jongens meer en meer naar de kampong achter de baboes aan velen hebben thuis verkering maar komen alleen bij die
# er alledrie ineens een hekel aan wat nu pasen de baboe geroepen en gevraagd eieren te halen op de pasar waren
# ik eigenlijk aan die rotzooi weer rap uit naar de baboe of naar de vuilniston heb met genoegen een blik geworpen
# zaak ingepakt ook de administratiekist en toen tidoeren vanmorgen was baboe vroeg present heb haar uitgebreide instructies gegeven over het schoonmaken
# de tuin bij het inpakken van de laatste spullen de baboe nog blij gemaakt met een paar hoofdkussens en andere zaken
# bekende achterblijvende jongens van andere onderdelen niet teveel naar de baboes kijken toen ik voorbij het huis van de ostcie liep
# bommenwerper de mitchel liberator btndit baadje hemdje benter babi varken baboe hulp in de huishouding huishoudster heros badge embleem insigne haik
# met triller in dit geval voor automotor boe kort voor baboe boeka open boe kit serillo de heuvel serillo boeng letterlijk
#
#
# Occurrences in Van infanterist tot radiomonteur : herinneringen van een Friese dorpsjongen aan zijn diensttijd als dienstplichtig militair in het voormalig Nederlands-Indie? 1947-1950 (03493.txt):
#
# bergpaardjes ervoor in de plaats van djongossen hebben we hier baboes die alleen voor de was zorgen dat is een hele
# 1950 we zijn letterlijk met de hele huishouding inclusief de baboes verhuisd naar djatiroto en zijn met vijftig autos van de
# het een gek land is hebben we gisteren meegemaakt onze baboe moest opeens bevallen de militaire dokter kwam met een ziekenauto
#
#
# Occurrences in 3-41 R.V.A. in de tropen (1948) (03494.txt):
#
# lieden werd geadviseerd wat meer afstand te bewaren tot de baboes die inmiddels ook een plaatsje in de cantine hadden ingenomen
# ernstigste symptoom op alle mogelijke en onmogelijke wijzen werden onze baboes en djongossen bedreigd en aangezet tot wapendiefstallen die ondanks de
# als postcommandant enkele weken zijn veldbed had gedeeld met een baboe ten aanschouwen van een aantal minderen zodoende tevens misbruik makende
#
#
# Occurrences in De stilte voorbij : het verhaal van Albert Scheer (03495.txt):
#
# met bestemming nederland onderweg doet albert een beroep op de reisbaboes die op de grote vaart op de kinderen passen en
# voor het doen van inkopen op die momenten krijgt de baboe vrijaf in semarang hebben ze nog een baboe voor de
# krijgt de baboe vrijaf in semarang hebben ze nog een baboe voor de was en het schoonmaken van het huis en
# doordat het kamp weer open is hebben sommige vrouwen hun baboe en kokki weer in dienst kunnen nemen het leven blijft
# minder bediendes in huis albert en marchien hebben alleen een baboe voor het doen van inkopen en om voor hen te
# Occurrences in Opdracht uitgevoerd : een verhaal over de Tweede Wereldoorlog die voor de Nederlandse jongens 10 jaar duurde (03498.txt):
#
# misverstandje op de cp m ngawi was een uitgebreid legertje baboes djongos en katjongs aanwezig die verschillende werk7 pkn!pten zo waste
# en katjongs aanwezig die verschillende werk7 pkn!pten zo waste een baboe wasvrouw oor 8 militairen dagelijks de tropenuniformen sokken als we
# was voorgevallen en kreeg het verhaal te horen dat de baboe de kamer waar hij sliep aan het vegen was toen
# om beiden uit te leggen waar de verontwaardiging van de baboe in besloten lag aan anema nota bene kandidaat drs economie
# had ik het adres gevonden en belde welgemoed aan de baboe deed open en ik vroeg naar de heer des huizes
# zag dat bijna ogenblikkelijk bevestigd mijn gastheer had namelijk de baboe 20 gulden meegegeven om op de pasar een slof sigaretten
# waren 21 gulden geworden zogenaamde dagprijzen enige malen werd de baboe voor stom dom en achterlijk uitgescholden en ze moest onmiddellijk
# belandas werkten niet zij lieten zich in nederland bedienen door baboes djongos en katjongs
# was elektrisch licht het huis werd grondig schoongehouden door de baboe die tevens dagelijks onze uniformen ondergoed en sokken waste op
# anak andjing angkat tangan a.n.j.v anklets a.p a.r.p atap awas baboe bahasa indonesia aanen afvoer troepen koosnaampje apen achter tralies zijn
#
#
# Occurrences in Agent in IndiÃ« : dagboekbrieven van een MP'er (1949-1950) (03499.txt):
#
# mogelijke rijsttafel hij wilde ons eens heerlijk laten eten de baboes begonnen de tafel van alle mogelijke lekkernijen te voorzien jacques
# en zijn duiven zijn twee aapjes en zijn uitzonderlijk mooie baboe op wie hij heel erg trots was nog even keken
#  page 143 higp ts m$fê de baboes en kat jongs van de bodjong  j mèêi fe4aw
# naar de achterzaal waar 40 man heerlijk hebben gegeten de baboes en de katjongs hadden voor alles gezorgd en alles was
# ginder holt een baboe met een grote stapel gewassen en gestreken kleren die ze
# schiet me echter een leuk verhaal te binnen over mijn baboe soeti en dat ga ik eerst vertellen ik denk dat
# o ja ook nieuws over een militaire missie soeti mijn baboe kwam even na zessen met een hoogrode kleur mijn kamer
# page 247 steeds voor dat een andere baboe present is om mijn was te doen want vanwege de
# dag gewassen worden een uurtje geleden hebben de jongens de baboes met een wagen teruggebracht naar de kampong morgenvroeg om zes
# weer raakte niemand gewond ze bleken de kamers van de baboes in ons kamp totaal te hebben leeggeroofd ik vind het
# in de benedenstad klaar ook van de verpleegsters op de merbaboeweg die me een hele tijd op het ziekenhuis verzorgden ben
# weten van aanpakken en omringen zich niet met een leger baboes en djongossen zoals de vrouwen met puur nederlands bloed doen
# lijst van maleise woorden alang-alang aloon-aloon ani-ani api atap baboe baik bandjir batik besar blanda djalan djeroek djongos gamelan goedang
#
#
# Occurrences in Brandlucht en bloedspoor : dagboek van een IndiÃ«ganger (03503.txt):
#
# een hospitaalsoldaat haalde een baboe die me moest masseren dat deed vreselijke pijn s avonds
# om vroeg naar bed te gaan door het bezoek van baboe issam duurde het echter lang voor er wat van slapen
# zijn huis naar de ü16 uer er0p 9.elegen cantine gingde baboes gingen in de vijfhonderd meter buiten het kamp liggende kalie
# woonden zeker vijftig evacuees en vluchtelingen het andere was voor baboes en djongossen gedurende de middag legden we een telefoonlijn van
# de haven van sabang 29-10-48 op wacht in de brenpunt baboe en djongos kobus handelslieden in de haven van aden
# a.h.k alang-alang aloon-aloon a.m.v.j anjing ans en herrie appèl a.p.r.a baboe babu bali desa banyak baroe baru baroe batik belanda bersiap
#
#
# Occurrences in Soldaat zonder franje (1928) (03507.txt):
#
# lag in de bergen aan de voet van de vulkanen merbaboe en de rokende merapi van knil militairen kregen we een
# waren iedere keer problemen bij de kampong waar we de baboe hadden afgezet de volgende dag gingen we in een grote
# bertus genaamd werken op de b-divisie hij had zijn persoonlijke baboe meegenomen maar dat mocht bij ons niet wij hadden een
# bij ons de boel opruimde en de bedden opmaakte zijn baboe verdween ergens in de kampong
#
#
# Occurrences in Herinneringen aan de 42e Zibva (03511.txt):
#
# senang vervolgens maakten we nog kennis met de ons toegewezen baboes en djongos zij zouden onze was verzorgen de kamers schoon
# gebracht om je te wassen en daarna kwam onze eigen baboe het ontbijt brengen dit vond ik persoonlijk het ergste er
# ontbijt overhandigd en snel maakte ze dat weg komt dezelfde baboe komt smiddags de nasi brengen en ze vindt het al
# dergelijks aan afval knagen allerlei soorten salamanders ritselen langs de baboewand en op het laatst is het of alles beweegt kruipt
# grote menigte bij de aanwervingsplaats ontzettend blij waren vooral de baboes als ze aangenomen werden want ze werden redelijk goed betaald
# dat hij er weer eens hard tegen aan ging de baboes jong en oud waren altijd erg opgewekt je hoorde ze
# oosthoek de mensen daar bleven in het algemeen vriendelijk de baboes katjongs koelies en ander burgerpersoneel bleven tot het einde voor
#
#
# Occurrences in Onze tijd in de Oost : een kittbag vol herinneringen : het reisdagboek van veteraan Geu Meulenbroeks gedurende de vredesstrijd in Oost-IndonesiÃ«. (03512.txt):
#
# we de eerste weken zelf doen al gauw komen de baboes dienstmeiden weer bij het peloton per zes of acht man
# het peloton per zes of acht man wordt er een baboe beschikbaar gesteld die de was en de strijk doet en
# deuren goed sloten konden we gewoon onder de klamboe de baboe deed de was en een paar djongos maakten de mestins
# mannen te praten de hulpen van de kok en de baboes liggen in een tent apart
# er zo hier en daar halfbloedjes geboren er werkt een baboe in ons kamp die zwanger was van een van de
# de school in sigoentoer moeda wordt het wilhelmus gezongen twee baboes moeder en dochter m i mm wmm mm k n
# de baboes doen de was voor 6 man is er een aangewezen
#
#
# Occurrences in 1940-1950 : 10 onrustige jaren. (03513.txt):
#
# hij vroeg wat ik wilde drinken koffie zei ik de baboe werd geroepen en die kwam even later dus met twee
# graag hij keek me wat vreemd aan maar riep de baboe en vervolgens kwamen er weer twee glazen koffie weer tien
# buitgemaakt dat was mede verbrand maar erger was dat de baboe die zich geweldig schuldig voelde ook nog het huisje ingegaan
# die zei met een soort wonderlijk lachje op zijn gezicht baboe idji tida ada
# er voor ons had gelegen die had een hele verzameling baboes achtergelaten daarbij gevoegd onze eigen organieke baboes was het langzamerhand
# een hele verzameling baboes achtergelaten daarbij gevoegd onze eigen organieke baboes was het langzamerhand een soort kakelend kippenhok geworden het gegiechel
# hebt kijk dan eerst eens naar die voeten van zon baboe en als je die spleettenen ziet dan heb je gegeten
#
#
# Occurrences in Drie warme jaren (1947) (03515.txt):
#
# veel wel moet hij nu zélf de koelies en de baboes aan het werk r zetten de groenten die bij de
# andere jongens voor één roepia in de week door de baboe doen als er wat te halen valt wat niks kost
# uit jos kan niet van zich af werken zodat de baboe iedere dag een schort broek en muts moet uitwassen terwijl
# met het werk ze let er bijvoorbeeld op dat de baboes de zaak niet flessen en omdat ze een javaanse is
# zien alleen af en toe de mannen alleen een oude baboe die de was verzorgt van de officieren en onderofficieren loopt
# zeven uur de kamer binnenkomt vindt hij één van de baboes in het bed van daan lamper liggen zonder sarong en
# dan het korte broekje heeft hij niet aan de andere baboe met de sapoe nog in de hand wijst op haar
# samen met enkele manschappen weg is geweest anders hadden de baboe en daan niet zo gek durven doen stomme daan denkt
# wel of ze geld overhouden wim de baar heeft een baboe die tevens bijslaap is jos verraste hem een keer toen
# echter niet waarom ze daar bang voor waren alleen die baboe van jullie vervolgt jacob heeft nog wel eens naar je
#
#
# Occurrences in De marsroute van 1-11 R.I. (03517.txt):
#
# de verbindingsgroep in het bivak van boeniseuri had een eigen baboe meegebracht het was een vlotte meid die bovendien een aardig
# toen gaf ze toe helemaal geen baboe maar een studente uit bandoeng te zijn behalve nederlands sprak
# naderend vertrek het werd tijd afscheid te nemen van de baboe en de djongos bediende die de manschappen veelal gedurende een
# Occurrences in Staphorster militairen in de tropen (03518.txt):
#
# de voet van de nogal eens vuurspuwende bergen van de merbaboe en merabi deze laatste berg is de gevaarlijkste en is
# een linke patrouille il op 1 mei 1948 zijn onze baboes vrouwelijke en djongossen mannen lijke indonesiche hulpjes met autos weggebracht
# t i baboe toerina stond tegen mij aan geleund te snikken als een
#
#
# Occurrences in Klappermelk & klompen : veteranen vertellen over Nederlands-IndiÃ« en Nieuw-Guinea (03519.txt):
#
# meer hoe ze zich moesten gedragen sommige mensen gebruikten hun baboe gewoon als slaaf ik geef je een voorbeeld een vrouw
# luie stoel riep als ze haar zakdoek liet vallen de baboe om hem op te rapen dat hoort niet ik deed

# %% [markdown]
# Dubbelklik in de bovenstaande cel en klik daarna op [shift] + [Enter]. In de vierkante haken linksboven buiten het veld, verschijnt dan een asterisk. Dit betekent dat de zoekactie in uitvoering is. Deze is afgerond als de asterisk verandert in een getal.
#
# Als je een ‘error’ krijgt, ga dan naar dit lijstje van de meest voorkomende errors met tips over hoe je die kunt oplossen.

# %% [markdown]
# In de bovenstaande code worden de resultaten simpelweg getoond in dit Notebook. Het kan uiteraard ook nuttig zijn om de resultaten te exporteren naar een tekstbestand, zodat deze resultaten dan ook weer in andere programma's (zoals Google sheets of Excel) kunnen worden bekeken of worden geanalyseerd. In die andere programma's kun je kolommen toevoegen, met, bijvoorbeeld, eigen commentaar of codes.
#
# Als je de resultaten van deze code wilt bewaren kun je deze naar een bestand exporteren via de onderstaande code. Die komen terecht op dezelfde plaats als waar dit notebook is opgeslagen. Het exportbestand heeft het *Comma Separated Value* (CSV) formaat. De naam van dit tekstbestand wordt bepaald door de variabele 'outFile'. De onderstaande code werkt alleen als eerst de bovenstaande code is uitgevoerd.
#
# In dit export bestand wordt ook het aantal treffers geteld. Naast het totaal aantal treffers wordt ook het aantal treffers per egodocument berekend.

# %%
# Hier specificeer je weer map van de corpus, de zoekterm, de window en nu ook de naam van het bestand waar de resultaten
# in opgeslagen worden (de "outFile")
dir = '../corpus'
search_term = 'baboe'
window = 10
outFile = 'concordantie'

# Maak een Pandas DataFrame aan, een soort grote tabel met extra functionaliteit. 
df = pd.DataFrame(columns = ['count_within_document','file','title','fragment'])

# Voor ieder bestand in de dir:
for file in os.listdir( dir ):
    
    # Als het een text bestand is dan ga door hier onder. Zo niet, ga terug naar boven naar het volgende bestand.
    if re.search( '[.]txt$' , file ):
        
        # Maak een variabele "documentCount" en zet die op 0. Deze variabele houdt bij hoeveel concordanties er zijn gevonden
        # in één boek.
        documentCount = 0 

        # Maak het pad naar het boek door het pad naar de corpus map en de naam van het bestand samen te voegen (join).
        # Open dit boek en sla dit op in de variabele "book". "encoding = 'utf-8'" zorgt ervoor dat de bits op het geheugen goed
        # naar letters worden omgezet
        book = open( join( dir , file ), encoding = 'utf-8' )
        
        # Zoek in het boek naar de zoekterm. re.IGNORECASE zorgt ervoor dat hoofdletters geen invloed hebben. 
        # Als de zoekterm in het boek gevonden is ga door hier onder. Zo niet, ga naar terug naar boven naar het volgende bestand.
        if re.search( search_term , book.read() , re.IGNORECASE ):
            
            # vind de titel van het bestand (showTitle(file)) en sla die op in de variabele "title".
            title = showTitle(file)
            
            # Verwieder de komma (,) in de titel.
            title = re.sub( ',' , '' , title )

            # Zoek alle concordanties (zo groot als de window) in het bestand (join) die de zoekterm bevatten (search_term).
            # sla ze op in de variabele "concordances"
            concordances = concordance( join( dir , file ) , search_term , window )
            
            # Voor iedere aparte gevonden concordantie (concordance) in alle gevonden concordancies (concordances) in het boek:
            for conc in concordances:
                
                # Tel één op bij het aantal gevonden concordanties in dit boek
                documentCount += 1
                
                # Maak een nieuwe rij in de tabel met de volgende opmaak. "kolom titel : variabele". 
                # Ga daarna verder naar de volgende concordantie in dit boek. Als er geen meer zijn: ga verder naar het volgende 
                # bestand.
                df = df.append({'count_within_document' : documentCount,
                                'file' : file, 'title' : title, 'match' : conc}, ignore_index = True)

# Wanneer alle boeken doorzocht zijn, sla de tabel op als een excel bestand in de map results, met de naam gespecificeerd in de
# variabele "outFile" plus de zoekterm.
df.to_excel("results/" + outFile + "_" + search_term + '.xlsx')
print("Excel bestand is opgeslagen")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319             try:
# --> 320                 self._store_workbook()
#     321             except IOError as e:
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     637         except IOError as e:
# --> 638             raise e
#     639
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     635             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 636                                 allowZip64=self.allow_zip64)
#     637         except IOError as e:
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/concordantie_baboe.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# <ipython-input-7-b1dec2ece635> in <module>
#      52 # Wanneer alle boeken doorzocht zijn, sla de tabel op als een excel bestand in de map results, met de naam gespecificeerd in de
#      53 # variabele "outFile" plus de zoekterm.
# ---> 54 df.to_excel("results/" + outFile + "_" + search_term + '.xlsx')
#      55 print("Excel bestand is opgeslagen")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2030             startcol=startcol,
#    2031             freeze_panes=freeze_panes,
# -> 2032             engine=engine,
#    2033         )
#    2034
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     740         )
#     741         if need_save:
# --> 742             writer.save()
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     191         Save workbook to disk.
#     192         """
# --> 193         return self.book.close()
#     194
#     195     def write_cells(
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     320                 self._store_workbook()
#     321             except IOError as e:
# --> 322                 raise FileCreateError(e)
#     323             except LargeZipFile as e:
#     324                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 2] No such file or directory: 'results/concordantie_baboe.xlsx'

# %% [markdown]
# Als je naar de resultaten van, bijvoorbeeld ‘baboe’ kijkt met 4 woorden ervoor en erna, blijkt het lastig duiding te geven aan de variëteit van de context waarin het woord voorkomt. Dit eerste hele basale voorbeeld is gekozen om het principe duidelijk te maken. We moeten daarom nu de opdracht uitbreiden.

# %% [markdown]
# Je zult je misschien afvragen waarom je met Python zou moeten zoeken, als je passages met een trefwoord ook in een gewone online zoekomgeving zou kunnen vinden. Het verschil is dat je met Python code veel flexibeler bent, en zelf kunt bepalen op welke manier gezocht wordt en in welke vorm de resultaten getoond worden. Ook is het makkelijker de resultaten te exporteren om ze verder te kunnen bewerken.
#
# **Oefening 1: Experimenteer eerst met een andere zoektermen en een ander bereik, bijvoorbeeld 20 woorden er voor en er na, door de waarden van de variabalen `search_term` en `window` aan te passen. Klik vervolgens op [Shift] + [Enter].**

# %% [markdown]
# ## 2. Collocatie - het tellen van woorden in de buurt van een term
#
# Net als bij een concordantie richt een collocatie-analyse zich op de context van specifieke zoektermen. Het verschil is dat bij een collocatie-analyse alle woorden in de context worden geteld. Op deze manier kan er een beeld ontstaan van de woorden die veel in de omgeving van een specifieke zoekterm worden gebruikt.
#
# In de code hieronder verwijst `search_term` weer naat de term waarnaar wordt gezocht, en `window` bepaalt weer het aantal woorden voor en na de opgegeven zoekterm.
#
# In de onderstaande code wordt ook de functie 'removeStopwords()' gebruikt. Deze functie heeft als effect dat de woorden die in alle documenten gemiddeld genomen even vaak voorkomen (bv. de, het, een wij, zijn, hebben, geweest, allen, doen, ik, jullie, etc.) en dus niet onderscheidend zijn voor een bepaald document, verwijderd worden.
#
# De onderstaande code zoekt in het gehele corpus, dat uit ca. 600 egodocumenten bestaat, en het uitvoeren van de code kan daarom enige tijd in beslag nemen. De analyse kan worden toegespitst op een specifieke periode. In de onderstaande code geeft de variabele 'start' het begin van de periode aan, en de variabele 'end' het einde. De code berekent alleen de woordfrequenties in de documenten die gepubliceerd zijn binnen de periode die op deze manier is vastgelegd.

# %%
# Maak drie variabelen, de dir (directory/map) corpus, de zoekterm 'baboe', en de search window: 30/
dir = '../toy_corpus'
searchTerm = 'baboe'
window = 30

# Maak een dictionary corpusFreq (een variabele die werkt in de vorm {key : value, key : value})
corpusFreq = dict()

# Voor ieder bestand in de map in de variabele dir ('corpus')
for file in os.listdir( dir ):
    
    # Als het bestand een tekst bestand is:
    if re.search( '[.]txt$' , file ):
#         print("Reading {}  ...".format( file ))

        # Vind de frequencies van alle woorden die voorkomen in de buurt van de zoekterm. Sla ze op in de variabele freq
        # "In de buurt" wordt dus aangegeven door de variabele 'window'
        freq = collocation( join( dir , file ) , searchTerm , window )
        
        # Verwijder de stopwoorden uit de gevonden collocaties 
        freq = removeStopwords( freq )
        
        # Voeg de gevonden collocaties zonder stopwoorden toe aan de variabele corpusFreq.
        corpusFreq.update(freq)
        
# Het aantal collocaties dat je wilt laten zien
max = 30

# De teller die bijhoudt hoeveel collocaties er zijn getoond.
i = 0
# Als er collocaties zijn gevonden:
if len(corpusFreq)> 0:
    
    # Sorteer de collocaties van hoog naar laag. "key = lambda x: corpusFreq[x]" is nodig voor het juist sorteren aangezien de
    # frequenties opgeslagen zijn in een dictionary (een data type). "reverse = True" zorgt ervoor het van hoog naar laag 
    # is gesorteerd (ipv de automatische laag naar hoog).
    corpusFreqSorted = sorted(corpusFreq, key = lambda x: corpusFreq[x], reverse = True)
    
    # Print het volgendende waarbij searchTerm de eerder gedefinieerde zoekterm is.
    print( f'The following words are used most frequently in the vicinity of "{ searchTerm }": \n' )

    # Voor iedere collocatie in de van hoog naar laag gesorteerde frequenties
    for f in corpusFreqSorted:
        
        # Teller plus 1
        i += 1
        # Laat het woord en de frequentie zien waarmee het voorkomt in de buurt van de zoekterm
        print( '{} =>  {}'.format( f , corpusFreq[f] ) )
        
        # Als er "max" (hierboven gedefinieerd) collocatie frequenties zijn getoond:
        if i == max:
            
            # Stop met laten zien
            break
            
else:
    print('\n\nThe search term you provided does not occur in the documents published during the selected period.')
# Out:
# The following words are used most frequently in the vicinity of "baboe":
#
# toe-eh =>  17
# siti =>  15
# weap =>  13
# i.d =>  8
# santani =>  6
# zittend =>  6
# stoffer =>  5
# jongetje =>  5
# boeng =>  5
# sigaretten =>  4
# veel =>  4
# enfin =>  4
# ketjil =>  4
# doodziek =>  4
# uitgehongerd =>  4
# tuin =>  4
# wiel =>  4
# dr =>  4
# strijkijzer =>  4
# toegewezen =>  4
# privékamer =>  4
# bericht =>  4
# bodja =>  4
# gescreend =>  4
# sapi =>  4
# ziekenhuis =>  4
# soeti =>  4
# lacht =>  3
# peter =>  3
# gaat =>  3

# %% [markdown]
# Wanneer je de code voor de collocatie-analyse hebt uitgevoerd kun je het resultaat opslaan met de code in de onderstaande cel. Deze code maakt een bestand aan met de naam 'collocation.csv' waarin de woorden en de frequenties terug te vinden zijn.

# %%
# Maximaal aantal woorden waarvan de frequentie wordt opgeslagen in excel bestand, gesorteerd van hoog naar laag.
max = 30

# De naam van het betand dat wordt opgeslagen.
outFile = 'collocation'

# Maak een Pandas DataFrame, een soort tabel met extra functionaliteit, met gespecificeerde kolom namen.
df = pd.DataFrame(columns = ["term", "frequency"])

# Een teller die op nul staat.
count = 0

# Voor ieder woord in de van hoog naar laag gesorteerde frequenties.
for f in corpusFreqSorted:
    
    # Voeg een rij toe aan het dataframe met de volgende structuur: {"naam van de kolom"} : waarde.
    df = df.append({"term" : f, "frequency" : corpusFreq[f]}, ignore_index = True)
    
    # Tel een op bij de teller
    count += 1
    
    # als het maximaal aantal woorden zijn toegevoegd aan het dataframe stop met toevoegen.
    if count == max:
        break
        
# Sla het DataFrame op als excel bestand.
df.to_excel(outFile + ".xlsx")

# %% [markdown]
# **Oefening 2: Voer een collocatie-analyse uit, aan de hand van een zoekterm die van belang kan zijn voor jouw onderzoek. Experimenteer met verschillende waarden voor de variabelen `search_term`, `window`.**

# %% [markdown]
# ## 3. Zoeken naar een combinatie van termen
#
# Als je op zoek bent naar samenhang tussen twee zaken wil je testen of de termen die naar die zaken verwijzen inderdaad in combinatie met elkaar voorkomen. Dan moet je bepalen op welke varianten van die twee termen je wilt zoeken en wat de minimale en maximale afstand tussen die termen moet zijn.
#
# In de onderstaande code kun je op de eerste plaats twee zoektermen opgeven, als waarden van `search_term1` en `search_term2`. De variabele `window` specificeert de maximale afstand tussen deze twee woorden.
#
# De code gaat vervolgens op zoek naar alle passages van de opgegeven lengte waar de beide zoektermen in voorkomen. De gevonden passages worden in dit notebook getoond wanneer de code wordt uitgevoerd, en de resultaten worden eveneens weggeschreven in een bestand met de naam 'cooccurrence.txt'.

# %%
from kitlvTdm import *
import os
from os.path import join
import re


# Defineer de zoektermen en de seach window
search_term1 = 'soldaat'
search_term2 = 'geweer'
window = 30

# In deze map gaat er gezocht worden
dir = "../toy_Corpus"

df = pd.DataFrame(columns = ['count_within_document','file','title','fragment'])

# Het zoeken is hoofdletter gevoelig, daarom worden alle hoofdletters in kleine letters veranderd
search_term1 = search_term1.lower()
search_term2 = search_term2.lower()

pattern = '####'


# Voor ieder bestand in de eerder gedefineerde map
for file in os.listdir( dir ):
    
    # Laat zien welk bestand het programma aan het lezen is
    print( "Reading " + file + ' ... ' )
    
    # Maak een lijst aan waar alle fragmenten in komen
    fragments = []
    
    # Als het bestand een tekst bestand is:
    if re.search( 'txt$' , file ):
        
        # Open het bestand en laad de tekst in de variabele 'fullText'
        with open( join( dir , file) , encoding = 'utf-8') as egodocument:
            fullText = egodocument.read()
            
        # Zoek en sla alleen de tekst op van iedere bladzijde (bijvoorbeeld niet het bladzijde nummer)
        fullText = re.sub( 'page\s+\d+', '' , fullText )
        
        # Verander alle hoofdletters in kleine letters
        fullText =  fullText.lower()
        
        # Identificeer de losse woorden
        words = tokenise(fullText)
        
        # Voor iedere locatie van een woord
        for i in range( 0 , (len(words)) ):
            
            # creeer een fragment van de grootte die gespecificeerd is in 'window'
            fragment = ' '.join( words[ i : window+i ] )
            
            # als de gezochte woorden beide voorkomen als los woord in het fragment
            if re.search( r'\b{}\b'.format(search_term1) , fragment , re.IGNORECASE ) and re.search( r'\b{}\b'.format(search_term2) , fragment , re.IGNORECASE ):
                
                '''
                Dit stukje zorgt ervoor dat een fragment niet vaker gevonden wordt. Als er één woord tussen soldaat en geweer zit
                en de 'window' is 30 zijn er 27 verschillende fragmenten voor dezelfde gevonden combinatie.
                Om dit te voorkomen wordt er gekeken of in een gevonden fragment de zoektermen op een andere manier tot elkaar staan
                en daarmee ook daadwerkelijk een nieuw fragment zijn.
                
                ! Dit herschrijven
                
                '''
                if not( re.search( pattern , fragment , re.IGNORECASE ) ):
                    
                    # Voeg het gevonden fragment toe aan de lijst fragments
                    fragments.append( fragment )
            
                    # Voor ieder nummer tussen 0 en het nummer 'window'
                    for findex in range( 0 , window ):
                        
                        # Als de het patroon al bekent is stop met de bovenstaande 'for loop'
                        if re.search( r'\b{}\b'.format(search_term1) , words[i + findex] , re.IGNORECASE ) or re.search( r'\b{}\b'.format(search_term2) , words[i + findex] , re.IGNORECASE ):
                            break
                    
                    # Anders update de variabele pattern naar het nieuw gevonden patroon
                    pattern = ' '.join( words[ i + findex : window+i  ] )

            # Tel een op bij de plek waar we zijn bij het doorzoeken van de woorden (bovenste for loop)
            i = window + i
            
    documentCount = 0
    # Als er hits gevonden zijn
    if len(fragments) > 0:
        
        # Vind de titel van het boek en sla het op in de variabele 'title'
        title = showTitle(file)
        
        # Laat het volgende zien met de titel en de naam van het bestand
        print("Occurrences in {} ({})\n".format( title , file ))
        
        # Voor ieder gevonden fragment 
        for fragment in fragments:
            
            documentCount += 1
            
            # Laat het fragment zien
#             print(h + '\n')
            
            # Schrijf het fragment op in het bestand
            df = df.append({'count_within_document' : documentCount,'file' : file, 'title' : title, 'fragment' : fragment}, ignore_index = True)


df.to_excel("testcoocurence.xlsx")
out.close()
# Out:
# Reading 03391.txt ...
# Reading 03392.txt ...
# Occurrences in De vergeten dagboeken (03392.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03393.txt ...
# Occurrences in Hij ging, kwam terug en keerde weer (03393.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03394.txt ...
# Reading 03395.txt ...
# Reading 03396.txt ...
# Occurrences in Als de natuur zwijgt (1945) (03396.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03398.txt ...
# Reading 03399.txt ...
# Occurrences in Herinneringen : memoires van een christen, militair en politicus (03399.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03400.txt ...
# Reading 03401.txt ...
# Reading 03402.txt ...
# Reading 03403.txt ...
# Reading 03404.txt ...
# Occurrences in IndonesiÃ« op het tweede gezicht : een laat weerzien met terugblikken naar toen (03404.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03405.txt ...
# Reading 03406.txt ...
# Reading 03407.txt ...
# Reading 03408.txt ...
# Reading 03409.txt ...
# Reading 03410.txt ...
# Reading 03411.txt ...
# Reading 03412.txt ...
# Reading 03413.txt ...
# Reading 03414.txt ...
# Reading 03415.txt ...
# Reading 03416.txt ...
# Occurrences in De grote patrouille : belevenissen van het bataljon 5-4 R.I. in Zuid- en Oost-Borneo, Zuid-Sumatra en Oost-Java in de jaren 1947, 1948, 1949, 1950 (03416.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03417.txt ...
# Reading 03418.txt ...
# Occurrences in Levenslang op patrouille (1946) (03418.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03419.txt ...
# Reading 03420.txt ...
# Reading 03421.txt ...
# Reading 03422.txt ...
# Reading 03423.txt ...
# Occurrences in De hemelse kwartiermaker : brieven van een jonge Maastrichtse oorlogsvrijwilliger aan zijn thuisfront, 1945-1947 (03423.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03424.txt ...
# Reading 03425.txt ...
# Occurrences in Verhalen van toen : Regiment Stoottroepen 50 jaar (03425.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03426.txt ...
# Reading 03427.txt ...
# Occurrences in Na vijftig jaar : dagboekherinneringen van een soldaat in Indie?, 1949-1950 (03427.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03428.txt ...
# Reading 03429.txt ...
# Occurrences in "Soldaat E. Kerkdijk : registratienummer 25.12.12.159 (03429.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03430.txt ...
# Reading 03431.txt ...
# Reading 03432.txt ...
# Occurrences in De laatste patrouille (1949) (03432.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03433.txt ...
# Reading 03434.txt ...
# Reading 03435.txt ...
# Reading 03436.txt ...
# Reading 03437.txt ...
# Occurrences in De laatste patrouille' : episode 1946-1950, Midden-Java (03437.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03438.txt ...
# Occurrences in Dikke zoen voor Moeke : brieven van een soldaat in IndiÃ« 1949-1950 (03438.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03439.txt ...
# Reading 03440.txt ...
# Reading 03441.txt ...
# Occurrences in Logboek 1-41 RVA : verhalen en wetenswaardigheden (03441.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03442.txt ...
# Reading 03443.txt ...
# Reading 03444.txt ...
# Reading 03445.txt ...
# Reading 03446.txt ...
# Reading 03447.txt ...
# Occurrences in Uust me? (03447.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03448.txt ...
# Reading 03449.txt ...
# Occurrences in Op patrouille in blessuretijd (1946) (03449.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03450.txt ...
# Reading 03451.txt ...
# Occurrences in Het dagboek van een gesneuvelde soldaat (1948) (03451.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03452.txt ...
# Occurrences in IndiÃ«-veteraan ben je levenslang (03452.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03453.txt ...
# Reading 03454.txt ...
# Reading 03455.txt ...
# Reading 03456.txt ...
# Occurrences in IndiÃ« blijft ons bezighouden (03456.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03457.txt ...
# Occurrences in Camouflagepak, politiepet en narrenkap (03457.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03458.txt ...
# Reading 03459.txt ...
# Reading 03460.txt ...
# Reading 03461.txt ...
# Reading 03462.txt ...
# Reading 03463.txt ...
# Reading 03464.txt ...
# Reading 03465.txt ...
# Reading 03466.txt ...
# Occurrences in Een Indonesie? weigeraar vertelt zijn verhaal : Jan Maassen over strijd en gevangenschap (03466.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03467.txt ...
# Occurrences in Respect en erkenning : veteranen Schaijk-Reek in Nederlands-Indie? 1945-1950 (03467.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03468.txt ...
# Reading 03469.txt ...
# Reading 03470.txt ...
# Occurrences in Een Zandbergse jongen : Indisch dagboek 1946 (03470.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03471.txt ...
# Reading 03472.txt ...
# Reading 03473.txt ...
# Reading 03474.txt ...
# Reading 03475.txt ...
# Reading 03476.txt ...
# Reading 03477.txt ...
# Reading 03478.txt ...
# Occurrences in Onhoorbaar groeit de padi : front-soldaten in een verloren oorlog : Indonesie 1948-1950 (03478.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03479.txt ...
# Occurrences in Indonesie? als eindstation : met het vergeten leger in Indie? (03479.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03480.txt ...
# Occurrences in Eens marinier altijd marinier : een leven vol afwisseling en avontuur : Qua Patet Orbis 1940-1972 (03480.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03482.txt ...
# Occurrences in Bij de inlichtingendienst op Midden-Java (03482.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03483.txt ...
# Reading 03484.txt ...
# Reading 03485.txt ...
# Reading 03486.txt ...
# Occurrences in Nou, tabee dan, ik groet je... : wetenswaardigheden van een vijfjarig verblijf in IndiÃ« 1945-1949 (03486.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03487.txt ...
# Reading 03488.txt ...
# Reading 03489.txt ...
# Reading 03490.txt ...
# Reading 03491.txt ...
# Occurrences in Duizend dagen IndiÃ« : het dagboek van Jan van Trigt 1945-1948 (03491.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03492.txt ...
# Reading 03493.txt ...
# Reading 03494.txt ...
# Occurrences in 3-41 R.V.A. in de tropen (1948) (03494.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03495.txt ...
# Reading 03496.txt ...
# Occurrences in IndiÃ« blijft onze denkwereld : met het vergeten leger in IndiÃ« (03496.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03497.txt ...
# Reading 03498.txt ...
# Occurrences in Opdracht uitgevoerd : een verhaal over de Tweede Wereldoorlog die voor de Nederlandse jongens 10 jaar duurde (03498.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03499.txt ...
# Reading 03500.txt ...
# Reading 03501.txt ...
# Reading 03502.txt ...
# Reading 03503.txt ...
# Reading 03504.txt ...
# Reading 03505.txt ...
# Reading 03506.txt ...
# Reading 03507.txt ...
# Occurrences in Soldaat zonder franje (1928) (03507.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03508.txt ...
# Reading 03509.txt ...
# Occurrences in Vaarwel, kameraad! : met het vergeten leger in Indie? (03509.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03510.txt ...
# Reading 03511.txt ...
# Occurrences in Herinneringen aan de 42e Zibva (03511.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03512.txt ...
# Reading 03513.txt ...
# Reading 03514.txt ...
# Reading 03515.txt ...
# Reading 03516.txt ...
# Occurrences in Het oerwoud beangstigt mij! : dagboek van een dienstplicht (03516.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03517.txt ...
# Occurrences in De marsroute van 1-11 R.I. (03517.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03518.txt ...
# Occurrences in Staphorster militairen in de tropen (03518.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03519.txt ...
# Occurrences in Klappermelk & klompen : veteranen vertellen over Nederlands-IndiÃ« en Nieuw-Guinea (03519.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03520.txt ...
# Reading 03521.txt ...
# Occurrences in Verhalen van veteranen : gesprekken met veteranen (03521.txt)
#
# om de boel op orde te krijgen wat uiteindelijk is gelukt al op 4 mei 1979 viel het eerste slachtoffer een geweer dat niet was vergrendeld ging af een soldaat
#
# Reading 03522.txt ...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319             try:
# --> 320                 self._store_workbook()
#     321             except IOError as e:
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     637         except IOError as e:
# --> 638             raise e
#     639
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     635             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 636                                 allowZip64=self.allow_zip64)
#     637         except IOError as e:
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#
# PermissionError: [Errno 13] Permission denied: 'testcoocurence.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# <ipython-input-13-081c8f601b84> in <module>
#     106 # Sluit het bestand
#     107
# --> 108 df.to_excel("testcoocurence.xlsx")
#     109 out.close()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2030             startcol=startcol,
#    2031             freeze_panes=freeze_panes,
# -> 2032             engine=engine,
#    2033         )
#    2034
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     740         )
#     741         if need_save:
# --> 742             writer.save()
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     191         Save workbook to disk.
#     192         """
# --> 193         return self.book.close()
#     194
#     195     def write_cells(
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     320                 self._store_workbook()
#     321             except IOError as e:
# --> 322                 raise FileCreateError(e)
#     323             except LargeZipFile as e:
#     324                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 13] Permission denied: 'testcoocurence.xlsx'

# %% [markdown]
# **Ofening 3: Ga, met behulp van de bovenstaande code, op zoek naar passages waarin twee relevante zoektermen in voorkomen. Pas de waarden van de variabelen `search_term1` en `search_term2` aan. Indien nodig kun je ook de waarde van `window` aanpassen.**

# %% [markdown]
# ## 4. Woordfrequenties - hoe vaak komt een woord voor in een document of een corpus?
#
# Welke woorden komen het meeste voor in een bepaald egodocument? De onderstaande code berekent de frequenties van alle woorden in een enkele tekst. De tekst waarin wordt gezocht wordt bepaald door de waarde van de variabele `egodocument`. De code toont vervolgens de 30 meest voorkomende woorden in deze tekst. De variabele `max` het aantal woorden dat wordt getoond.
#
# Ook hier is het van belang de stopwoordenlijst te gebruiken om alleen zinvolle frequenties in de resultaten terug te krijgen die te maken hebben met de inhoud, en om niet ter zake doende lidwoorden, bijwoorden en voorzetsels er uit te filteren.

# %%
# Specificeer de map waar de corpus staat (dir), de naam van het document (egodocument) en het maximaal aantal woorden waarvan
# de frequentie wordt getoond (max).
dir = '../corpus'
egodocument = '03391.txt'
max = 30

# Vind de frequenties van alle woorden in het boek.
freq = calculateWordFrequencies(join( dir, egodocument))

# Verwijder de stopwoorden uit de frequenties
freq = removeStopwords(freq)

# Sorteer de frequenties van hoog naar laag. "key=lambda x: freq[x]" is nodig voor het juist sorteren aangezien de frequenties
# opgeslagen zijn in een dictionary (een data type). "reverse = True" zorgt ervoor het van hoog naar laag is gesorteerd
sorted_f = sorted(freq, key=lambda x: freq[x], reverse = True)
print(sorted_f)

# Laat het volgende zien waarbij showTitle de titel van het egodocument laat zien.
print( f'The following words occur most frequently in the text { egodocument } ({ showTitle( egodocument )}).\n' )

# Maak een teller die bij houdt hoeveel woorden er zijn laten zien.
count = 0

# Voor iedere frequentie in de van hoog naar laag gesorteerde lijst met frequenties:
for f in sorted_f:
    
    # Laat het woord en de frequentie zien. ".format" vult de "{}" in. Hier met respectievelijk het woord (f) en de frequentie
    # van het woord f (freq[f]).
    print( '{} => {}'.format(f, freq[f]))
    
    # Tel een op bij het aantal woorden wat er is getoond
    count += 1
    
    # Als het maximale aantal woorden is getoond, stop met laten zien
    if count == max:
        break
# Out:
# ['indonesië', 'indonesische', 'tijd', 'cpn', 'nederland', 'partij', 'pki', 'nederlandse', 'veel', 'waarheid', 'ging', 'kwam', 'groot', 'enkele', 'politiek', 'grote', 'zoals', 'oorlog', 'jaren', 'paar', 'redactie', 'indonesiërs', 'kreeg', 'land', 'wilde', 'keer', 'chinese', 'sukarno', 'jaar', 'goed', 'bleef', 'situatie', 'aantal', 'suharto', 'krant', 'communistische', 'strijd', 'politieke', 'artikel', 'an', 'nieuwe', 'mensen', 'bleek', 'gaf', 'één', 'bezoek', 'joop', 'amsterdam', 'china', 'maken', 'enige', 'schreef', 'dagen', 'artikelen', 'zei', 'ter', 'maakte', 'deel', 'eigen', 'doen', 'internationale', 'moskou', 'plaats', 'communisten', 'aandacht', 'lid', 'men', 'jakarta', 'regering', 'laten', 'komen', 'huis', 'soms', 'zelf', 'toe', 'geven', 'annie', 'naam', 'boeken', 'tweede', 'militaire', 'gehouden', 'koloniale', 'reis', 'terug', 'blijven', 'militairen', 'daarbij', 'paul', 'kwamen', 'wordt', 'cultuur', 'vrienden', 'partijen', 'wolff', 'buitenlandse', 'sowjet-unie', 'af', 'geheel', 'contact', 'thuis', 'praag', 'mei', 'weken', 'landen', 'zaken', 'delegatie', 'kamer', 'begin', 'werk', 'moment', 'gemaakt', 'per', 'nationale', 'republiek', 'vond', 'begon', 'gelegenheid', 'gingen', 'zeggen', 'september', 'stand', 'duidelijk', 'zeer', 'deed', 'judy', 'brief', 'vanaf', 'heel', 'betrekkingen', 'minister', 'laatste', 'drie', 'leiding', 'vertelde', 'steun', 'geschiedenis', 'belangrijke', 'waarin', 'lag', 'zag', 'vorming', 'wim', 'indië', 'wilden', 'zeker', 'februari', 'nam', 'indonesisch', 'vrouw', 'periode', 'eind', 'viel', 'bestuur', 'sprak', 'liet', 'makassar', 'bestaan', 'beweging', 'wil', 'geschreven', 'geworden', 'discussie', 'rol', 'staat', 'elkaar', 'weinig', 'besloten', 'congres', 'nooit', 'augustus', 'uur', 'bestond', 'bijvoorbeeld', 'oktober', 'conferentie', 'boek', 'meestal', 'nederlands', 'maart', 'gekomen', 'eigenlijk', 'indonesia', 'stond', 'lange', 'jaap', 'samenwerking', 'averink', 'president', 'maanden', 'betreft', 'verscheen', 'blad', 'bijzonder', 'tegenover', 'hand', 'henk', 'praten', 'gedaan', 'njoto', 'optreden', 'leven', 'gevraagd', 'juli', 'algemeen', 'nemen', 'natuurlijk', 'leden', 'geval', 'houden', 'kort', 'bekend', 'bracht', 'piet', 'zoveel', 'verhouding', 'zien', 'betekenis', 'iets', 'kende', 'anjv', 'via', 'gevoel', 'dagelijks', 'jonge', 'economische', 'andré', 'werkzaamheden', 'los', 'orde', 'brieven', 'sprake', 'vertrek', 'direct', 'vele', 'werkte', 'discussies', 'weten', 'woorden', 'juni', 'snel', 'staten', 'indonesië-commissie', 'commissie', 'uiteraard', 'jongeren', 'jong', 'hield', 'houding', 'ondermeer', 'actief', 'tenslotte', 'gekozen', 'kleine', 'samen', 'comité', 'pvda', 'peking', 'buitenland', 'activiteiten', 'bvd', 'berichtgeving', 'organisatie', 'verkiezingen', 'volk', 'marcus', 'verzet', 'zat', 'leek', 'woonde', 'amerikaanse', 'gebracht', 'begonnen', 'bezocht', 'pegasus', 'persoonlijke', 'wereld', 'voorzitter', 'daarvoor', 'jongens', 'manier', 'vonden', 'lang', 'betrekking', 'november', 'bleven', 'gezien', 'gezegd', 'onafhankelijkheid', 'rakjat', 'ontwikkelingen', 'gebeurtenissen', 'woord', 'naast', 'hoofdredacteur', 'gang', 'vertegenwoordigers', 'bezetting', 'krijgen', 'dr', 'revolutie', 'stelde', 'omstandigheden', 'chinezen', 'volksrepubliek', 'russische', 'ontmoeting', 'ontwikkeling', 'russisch', 'foto', 'ontmoetingen', 'gesproken', 'schrijven', 'staan', 'belangstelling', 'bakker', 'vragen', 'noemde', 'zetten', 'lezen', 'zowel', 'daardoor', 'ouders', 'langer', 'niets', 'ruim', 'ontvangen', 'solidariteit', 'morriën', 'ambonezen', 'namen', 'holland', 'titel', 'week', 'gegeven', 'oude', 'nauwelijks', 'meest', 'aanvankelijk', 'december', 'vraagstuk', 'mogelijk', 'speciale', 'duurde', 'vrouwen', 'gepubliceerd', 'aidit', 'gemeenschappelijke', 'gesteld', 'beetje', 'wist', 'dienst', 'minder', 'parlement', 'verenigde', 'korte', 'vraag', 'heen', 'april', 'stonden', 'ontstond', 'meeste', 'genomen', 'gehele', 'overleg', 'kregen', 'stad', 'gevangenen', 'felix', 'aanwezig', 'boeren', 'tijdschrift', 'ber ...
# The following words occur most frequently in the text 03391.txt (Indonesie? liet me nooit meer los : vijftig jaar antikoloniale strijd).
#
# indonesië => 424
# indonesische => 246
# tijd => 196
# cpn => 187
# nederland => 178
# partij => 174
# pki => 165
# nederlandse => 153
# veel => 150
# waarheid => 144
# ging => 143
# kwam => 131
# groot => 130
# enkele => 125
# politiek => 116
# grote => 115
# zoals => 101
# oorlog => 100
# jaren => 97
# paar => 97
# redactie => 88
# indonesiërs => 86
# kreeg => 86
# land => 86
# wilde => 85
# keer => 83
# chinese => 83
# sukarno => 82
# jaar => 81
# goed => 80

# %% [markdown]
# **Oefening 4: Bepaal de meest frequente woorden in een van de egodocumenten in het corpus van "Soldaat in Indonesië". Experimenteer met verschillende waarden voor de variabelen `egodocument` en `max`.**

# %% [markdown]
# De woordfrequenties geven deels een vertekend beeld, omdat in veel memoires letterlijk passages of hele delen van dagboeken uit de tijd zelf worden gebruikt. Eigenlijk zou je die boeken die verhoudingsgewijze veel van deze teksten bevatten moeten kunnen isoleren, zodat de boeken zonder deze passages kunnen worden geanalyseerd. Dat kan alleen door extra codes aan de publicaties toe te voegen die dit verschil aangeeft. Die laag is er nu nog niet, maar staat wel in de planning.
#
# Veranderingen in woordgebruik zijn gebonden aan tijd en veranderingen in de samenleving. Omdat dit corpus zich uitstrekt vanaf de periode van het conflict zelf (1945-1949) tot aan 2017, is het interessant om het voorkomen van bepaalde termen chronologisch te vergelijken. De onderstaande code verdeelt het corpus in perioden van 5 jaar, en berekent vervolgens de woordfrequenties voor de egodocumenten die in deze verschillende tijdvakken verschenen. Hierbij moet wel de kanttekening worden geplaatst dat niet alle egodocumenten konden worden gedateerd. Bij deze analyse worden de teksten die nog niet zijn gedateerd genegeerd. Verder is het uiteraard ook zo dat er een onevenredige verdeling is van het aantal boeken over deze perioden. De absolute frequenties kunnen daardoor niet zonder meer worden vergeleken. OM de frequenties toch vergelijkbaar te maken zijn de absolute tellingen steeds gedeeld door het totaal aantal woorden in de egoducmenten uit de verschillende perioden.
#
# De lengte van de geanlyseerde periode kan overgens worden aangepast via de variabele `period_length`.
#
# De resultaten worden getoond in dit Notebook, maar worden eveneens weggeschreven in een bestand met de naam `frequency_chronological.csv`.

# %%
from kitlvTdm import *
import os
from os.path import join



start = 1930
end = 2020
period_length = 5
nr_words = 20

dir = 'Corpus'

def sortedByValue( dict ):
    return sorted( dict , key=lambda x: dict[x])

intervals = []

out = open( 'frequency_chronological.csv' , 'w' , encoding = 'utf-8' )
out.write( 'year_from,year_to,tokenCount,term,frequency\n' )

for year in range( start , end , period_length ):
    intervals.append(year)

for year in intervals:
    year_from = year
    year_to =  period_length -1 + year

    freqTotal = dict()
    tokensTotal = 0
    egodocuments = 0

    for file in os.listdir(dir):
        if re.search( 'txt$' , file ):
            year = showYear( file )
            if year is not None:
                if year >= year_from and year <= year_to:
                    egodocuments += 1
                    freq = calculateWordFrequencies( join( dir, file ) )
                    freqTotal.update(freq)
                    tokensTotal += numberOfTokens( join( dir, file ) )

    print( f'\n{ year_from }-{ year_to }\n{tokensTotal} words in total in {egodocuments} egodocuments\n\n' )


    freqTotal = removeStopwords( freqTotal )

    count = 0
    for word in reversed( sortedByValue(freqTotal) ):
        out.write( f'{year_from},{year_to},{tokensTotal},{word},{freqTotal[word]}\n' )
        print( f' { word } => { freqTotal[word] / tokensTotal }' )
        count += 1
        if count == nr_words:
            break

out.close()

# %% [markdown]
# **Oefening 4: Probeer met behulp van de bovenstaande code te verkennen hoe het woordgebruik zich ontwikkelde over de loop van de afgelopen decennia. Verander hiervoor de waarde van de variabelen `period_length` en `nr_words`.**

# %% [markdown]
# Woordsoorten als zelfstandige naamwoorden, bijvoeglijke naamwoorden en werkwoorden drukken zijn over het algemeen het meest bepalend voor de betekenis van zinnen. Het kan daarom nuttig en informatief zijn om frequentie-analyses te beperken tot dit soort woorden. In de onderstaande cellen worden uitsluitend de zelfstandige naamwoorden, bijvoeglijke naamwoorden en werkwoorden geteld, door gebruik te maken van de hierboven al genoemde module `nltk`. Deze module richt zich normaal gesproken op Engelstalige teksten. Om `nltk` ook toe te kunnen passen op Nederlandstalige teksten moet eerst de onderstaande code worden uitgevoerd.

# %%
import nltk
nltk.download('alpino')

from nltk.corpus import alpino as alp
from nltk.tag import UnigramTagger, BigramTagger
training_corpus = alp.tagged_sents()
unitagger = UnigramTagger(training_corpus)
bitagger = BigramTagger(training_corpus, backoff=unitagger)
pos_tag = bitagger.tag

# %% [markdown]
# Als de installatie van de Nederlandstalige variant van `nltk` geen problemen opleverde, kan de onderstaande, meer gerichte frequentie-analyse worden uitgevoerd. Let er hierbij op dat het toekennen van grammaticale categorieën wel enige rekenkracht vergt. Het uitvoeren van de code kan dus enige tijd in beslag nemen.

# %%
from kitlvTdm import *
import os
from os.path import join


nr_words = 100

dir = 'Corpus'
egodocument = '03391.txt'

def sortedByValue( dict ):
    return sorted( dict , key=lambda x: dict[x])



out = open( 'frequency_POS.csv' , 'w' , encoding = 'utf-8' )
out.write( 'word,frequency\n' )



freqTotal = dict()

countFile = 0 

for file in os.listdir(dir):
    if re.search( 'txt$' , file ):
        countFile += 1
        if file == egodocument:
        #print( '\rReading {} ... ({}/577)'.format(file , countFile ) )
            with open( join( dir, file ) ) as fileName:
                fullText = fileName.read()
                sent = sent_tokenize(fullText)
                for s in sent:
                    words = word_tokenize(s)
                    pos = pos_tag(words)
                    for p in pos:
                        if p[1] is not None:
                            if re.search( r'^(adj)|(noun)|(verb)' , p[1] ):
                                freqTotal[ p[0]  ] = freqTotal.get( p[0] ,0 ) + 1


freqTotal = removeStopwords( freqTotal )

for word in reversed( sortedByValue(freqTotal) ):
    out.write( f'{word},{freqTotal[word]}\n' )
    print( f' { word } => { freqTotal[word] / tokensTotal }' )
    count += 1
    if count == nr_words:
        break

out.close()

# %% [markdown]
# **Oefening 5: Probeer een lijst te generen van de 150 meest frequente zelfstandige naamwoorden, bijvoeglijke naamwoorden en werkwoorden.**

# %% [markdown]
# # 5. Distributiegrafiek

# %% [markdown]
# Historische ontwikkelingen kunnen ook op een andere manier worden geanalyseerd. Appplicaties zoals de [Google Books Ngram viewer](https://books.google.com/ngrams) maken gebruik van distributie-grafieken waarin woordfrequenties per jaar worden berekend. De onderstaande ocde doet iets vergelikbaar voor het corpus van "Soldaat in Indonesië". Zoals te zien is in de eerste regels van de onderstaande cel wordt er eerst een lljst van woorden opgegeven. Deze woorden worden allemaal vastgelegd onder de naam `search_terms`. De code berekent vervolgens per jaar hoe vaak deze woorden zijn gebruikt. De resultaten worden vastgelegd in een CSV-bestand waarin de relatieve frequenties (het aantal voorkomens va deze woorden, gedeeld door het totaal aantal woorden in dat jaar) worden vastgelegd.

# %%
import re

search_terms = '''
gestoken
vuur
schieten
gevangen
doodgeschoten
schoten
neergeschoten
gevangenen
patrouille
gevangene
dood
geschoten
soldaten
doden
bloed
geweer
gedood
wapens
beschoten
schoot
kogel
gewonden
geslagen
vermoord
verhoord
zuiveringsactie
hinderlaag
slachtoffers
executie
patrouilles
wraak
inlichtingendienst
extremisten
kogels
woede
moord
mortieren
krijgsraad
vuurgevecht
incident
kampement
gewonde
handgranaat
vluchtende
gevecht
geëxecuteerd
pistool
gewond
oorlog
fik
tegenstanders
krijgsgevangenen
strijd
mitrailleur
spion
platgebrand
kapot
afgebrand
zuivering
bajonet
salvo
mishandeld
omsingeld
granaten
gevangengenomen
bataljon
vernietigd
represaille
beschieting
tegenpartij
terroristen
plunderaars
doodschieten
brandende
hardhandig
moordenaars
genadeschot
pijn
revolver
gemarteld
gefusilleerd
mes
wapen
aangevallen
neerschieten
gezuiverd
brandde
plunderen
vijanden
beschietingen
gedreigd
geplunderd
slaag
executeren
aanslag
geschreeuw
handgranaten
afschuwelijke
gebombardeerd
verminkt
gemene
burgerslachtoffers
plundering
plunderingen
krijgsgevangene
moorden
excessief
geweldsexcessen
mishandeling
gevechten
sadistische
vuurstoot
weerloze
martelen
executies
doodgeslagen
schreeuwde
schietend
onthoofd
represailles
fosforgranaten
verminkte
gruwelijk
nekschot
tegenaanval
overval
verwond
moordenaar
bewapend
opblazen
executiepeloton
verkracht
vuurstoten
vuurwapens
vergelding
beestachtige
doodstraf
trekker
stervende
neergeknald
platbranden
artillerie
bedreiging
slachting
verwondingen
vreselijke
ontgelden
gummiknuppel
knallen
gevaarlijk
slachtoffer
marteling
beestachtig
platgeschoten
lijden
uitgemoord
schietpartij
bloedbad
mortiergranaten
misdadigers
massagraf
gruwelijke
afgehakt
kapmes
bombardement
schokkende
zuiveringsopdracht
'''

search_terms = search_terms.strip()
terms_list = re.split( r'\n' , search_terms.lower() )



frequency_year = dict()
word_count_year  = dict()
    
dir = 'corpus'

corpusFreq = dict()



for file in os.listdir( dir ):
    if re.search( '[.]txt$' , file ):
        print( f"Reading { file } ..." )
        if showYear( file ) is not None:
            year = int(showYear( file ) )
            freq = calculateWordFrequencies( join( dir , file ) )
            freq = removeStopwords( freq )
            tokens = numberOfTokens( join( dir , file ) )
            word_count_year[ year ] = word_count_year.get( year , 0 ) + tokens
            for term in terms_list:
                if term in freq:
                    frequency_year[year] = frequency_year.get( year , 0 ) + freq[ term ]

                
            
out = open( 'dispersion_data.csv', 'w' , encoding = 'utf-8' )
out.write( 'year,frequency\n' )

for year in sorted( frequency_year  ):
    out.write( '{},{}\n'.format( year , frequency_year[ year ] / word_count_year[year] ) )
    print( '{} times in {}.'.format( frequency_year[ year ] , year ) )

out.close()

print('The CSV file has been created.')

# %% [markdown]
# De frequenties kunnen hierna worden gevisualiseerd met de onderstaande code.

# %%
# %matplotlib inline

import pandas as pd
df = pd.read_csv( 'dispersion_data.csv' )

import matplotlib.pyplot as plt

plt.style.use('ggplot')

fig = plt.figure( figsize = ( 15, 4))
ax = plt.axes()

ax.plot( df['year'] , df['frequency'] , color = '#930d08' , linestyle = 'solid')

ax.set_xlabel('Years')
ax.set_ylabel('Word frequency')


ax.set_xlim( df['year'].min() , df['year'].max() )

ax.set_title( 'Dispersion graph')

plt.show()

# %% [markdown]
# **Oefening 6: Pas de waarde van de variabele `search_terms` aan. Geef een aantal woorden op die van belang zijn voor jouw onderzoek. Probeer hierna een distributiegrafiek te maken die de historische ontwikkelingen in het gebruik van deze termen kan verduidelijken.**
